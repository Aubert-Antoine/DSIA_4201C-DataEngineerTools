# %% [markdown]
# # Introduction
#
# [Scrapy](https://scrapy.org/) est un framework permettant de crawler des
# sites web et d'en extraire les données de façon structurée.
#
# ## Installation
#
# Nous travaillerons dans un environnement
# [Anaconda](https://www.anaconda.com/download/), déjà présent sur les
# machines de l'ESIEE. Sur vos machines personnelles, télécharger la
# distribution correspondant à la version la plus récente de Python.
#
# [Scrapy](https://scrapy.org/) ne fait pas partie de la distribution par
# défaut de Python et doit être installé manuellement. Ici, le package est
# déjà installé grâce à Pipenv.
#
# Si vous avez besoin d'installer dans un autre cadre.
#
# -   Avec **Pipenv** : `pipenv install scrapy`
# -   Avec **Anaconda** : `conda install -c conda-forge scrapy`
#
# Tester la réussite de l'opération dans un interpréteur Python. Avant
# installation:

# %%
# !pip install scrapy

# %%
import scrapy

# %% [markdown]
# ## Architecture
#
# [Scrapy](https://scrapy.org/) est un framework comportant plusieurs
# composants.
#
# <img src="images/architecture.png" alt="image" class="align-center" />
#
# L'ensemble du processus est contrôlé par l'**engine** (les termes anglo
# saxons ont été retenus pour un meilleur référencement dans la
# [documentation officielle](https://docs.scrapy.org/en/latest/)).
#
# Le framework est articulé avec plusieurs composants qui gèrent chacun un
# rôle différent. Nous allons les détailler.
#
# -   Les **Spiders** : permettent de naviguer sur un site et de
#     référencer les règles d'extraction de la donnée.
# -   Les **Pipelines** : font le lien entre la donnée brute et des objets
#     structurés
# -   Les **Middlewares** : permettent d'effectuer des transformations sur
#     les objets ou sur les requêtes exécutées par l'engine.
# -   Le **Scheduler** : gère l'ordre et le timing des requêtes
#     effectuées.
#
# ## Fonctionnement
#
# [Scrapy](https://scrapy.org/) est entièrement organisé autour d'un
# composant central : l'*engine*.
#
# Le rôle de l'*engine* est de contrôler le flux de données entre les
# différents composants du système.
#
# 1.  En particulier, il est chargé de récupérer les *requests* définies
#     dans les *spiders*
# 2.  Ces *requests* sont ensuite fournies au *scheduler* qui se charge de
#     leur ordonnancement
# 3.  Les *requests* sont présentées selon cet ordonnancement à
#     l'*engine*...
# 4.  ... qui les transmet au *downloader*
# 5.  Le *downloader* effectue la *request* et transmet la *response* (le
#     contenu de la page web) à l'*engine*...
# 6.  ... puis l'envoie au *spider* pour traitement
# 7.  Le *spider* génére des *items* qui sont transmis à l'*engine*
# 8.  Les *items* sont ensuite poussés dans un pipeline pour nettoyage,
#     validation et stockage
#
# Ce processus est répété jusqu'à épuisement des requêtes.
#
# [Scrapy](https://scrapy.org/) est un [framework orienté
# événements](https://en.wikipedia.org/wiki/Event-driven_architecture)
# (basé sur [Twisted](https://twistedmatrix.com/)) permettant une
# programmation asynchrone (non bloquante). C'est particulièrement
# intéressant dans les opérations de scraping, puisque **le programme
# n'attend pas le résultat d'une requête pour en lancer une autre**.
#
# En effet, lorsque l'on sollicite une ressource (requête réseau, système
# de fichier, etc.) en mode bloquant, l'exécution du programme est
# suspendue le temps que la transaction avec la ressource se termine (par
# exemple le temps qu'une page web soit complètement téléchargée).
# L'intérêt de faire des appels non bloquants, c'est que l'on peut gérer
# de multiples téléchargements en parallèle, et que le programme peut
# continuer à tourner pendant ce temps.

# %% [markdown]
# # Un scraping élémentaire
#
# Avant de rentrer dans les détails du framework, nous allons mettre en
# oeuvre un premier script permettant de récupérer l'information présente
# sur [la page web](http://evene.lefigaro.fr/citations/winston-churchill)
# recensant les citations de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill).
#
# **Exercice**
#
# Examiner le code source de cette page avec l'inspecteur de votre
# navigateur. Identifier les éléments contenant l'information recherchée,
# ici la chaîne de caractères contenant la citation proprement dite.
#
# ## Le code source
#
# Le code utilisé est le suivant:

# %%
# %load citations_churchill_spider1.py
import scrapy

class ChurchillQuotesSpider(scrapy.Spider):
    name = "citations de Churchill"
    start_urls = ["http://evene.lefigaro.fr/citations/winston-churchill",]

    def parse(self, response):
        for cit in response.xpath('//div[@class="figsco__quote__text"]'):
            text_value = cit.xpath('a/text()').extract_first()
            yield { 'text' : text_value }

# %% [markdown]
# ## Le fonctionnement
#
# Le fonctionnement est le suivant:
#
# -   On importe le module [Scrapy](https://scrapy.org/) (3)
# -   et on définit une sous classe de `scrapy.Spider` (5)
# -   la variable `start_urls` contient la liste des pages à scraper (7)
# -   On redéfinit la méthode $parse$ dont la signature est définie dans
#     la classe mère (9)
# -   L'objet
#     [response](https://docs.scrapy.org/en/latest/topics/request-response.html#response-objects)
#     représente la réponse à la requête HTTP (l'attribut $text$ permet
#     d'accéder à son contenu). On recherche ensuite tous les containers
#     `<div>` identifiés dans l'exercice précédent. Ici la page est
#     particulièrement bien structurée et les citations disposent de leur
#     propre container, identifié par l'attribut `class` de valeur
#     `figsco__quote__text`. La sélection se fait par une expression
#     [XPath](https://en.wikipedia.org/wiki/XPath), un langage de
#     sélection de noeud dans un document XML (10). En langage naturel, la
#     requête pourrait se formuler : "On recherche tous les containers
#     `<div>` dont la valeur de l'attribut `class` est égal à
#     `figsco__quote__text`".
# -   Pour chaque résultat, on construit un dictionnaire dont la clé est
#     `text` et la valeur le contenu du lien `<a>`. Ce résultat est fourni
#     par un générateur ($yield$) (12).
#
# On lance le scraping depuis un terminal:

# %%
# !scrapy runspider citations_churchill_spider1.py
# Out:
# 2019-11-25 12:52:30 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: scrapybot)
# 2019-11-25 12:52:30 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.7.3 (default, Mar 27 2019, 16:54:48) - [Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Darwin-18.6.0-x86_64-i386-64bit
# 2019-11-25 12:52:30 [scrapy.crawler] INFO: Overridden settings: {'SPIDER_LOADER_WARN_ONLY': True}
# 2019-11-25 12:52:30 [scrapy.extensions.telnet] INFO: Telnet Password: 7d292963a3bbe416
# 2019-11-25 12:52:30 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2019-11-25 12:52:30 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-11-25 12:52:30 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-11-25 12:52:30 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-11-25 12:52:30 [scrapy.core.engine] INFO: Spider opened
# 2019-11-25 12:52:30 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-11-25 12:52:30 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2019-11-25 12:52:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': '“Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.”'}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': "“Un conciliateur c'est quelqu'un qui nourrit un crocodile en espérant qu'il sera le dernier à être mangé.”"}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': '“Il est une bonne chose de lire des livres de citations, car les citations lorsqu’elles sont gravées dans la mémoire vous donnent de bonnes pensées.”'}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': "“Je suis toujours prêt à apprendre, bien que je n'aime pas toujours qu'on me donne des leçons.”"}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': "“C'est une belle chose d'être honnête, mais il est également important d'avoir raison.”"}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': '“J’ai retiré plus de choses de l’alcool que l’alcool ne m’en a retirées.”'}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': "“Pour s'améliorer, il faut changer. Donc, pour être parfait, il faut avoir changé souvent.”"}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': "“On considère le chef d'entreprise comme un homme à abattre, ou une vache à traire. Peu voient en lui le cheval qui tire le char.”"}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': '“En Angleterre, tout est permis, sauf ce qui est interdit. En Allemagne, tout est interdit, sauf ce qui est permis. En France, tout est permis, même ce qui est interdit. En U.R.S.S., tout est interdit, même ce qui est permis.”'}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': '“On vit de ce que l’on obtient.\rOn construit sa vie sur ce que l’on donne.”'}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': "“Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.”"}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': '“Plus vous saurez regarder loin dans le passé, plus vous verrez loin dans le futur.”'}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': '“L’Angleterre s’écroule dans l’ordre, et la France se relève dans le désordre.”'}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': "“En avalant les méchantes paroles qu'on ne profère pas, on ne s'est jamais abîmé l'estomac.”"}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': '“Comité : Un groupe de personnes incapables de faire quoi que ce soit par elles-mêmes qui décident collectivement que rien ne peut être fait !”'}
# 2019-11-25 12:52:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': "Les mots sont comme les sacs : ils prennent la forme de ce qu'on met dedans."}
# 2019-11-25 12:52:30 [scrapy.core.engine] INFO: Closing spider (finished)
# 2019-11-25 12:52:30 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 243,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 15103,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.172281,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2019, 11, 25, 11, 52, 30, 760887),
#  'item_scraped_count': 16,
#  'log_count/DEBUG': 17,
#  'log_count/INFO': 10,
#  'memusage/max': 50716672,
#  'memusage/startup': 50716672,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2019, 11, 25, 11, 52, 30, 588606)}
# 2019-11-25 12:52:30 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On y trouve des informations sur les paramètres
# utilisés:

# %%
2018-01-10 17:21:05 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
2018-01-10 17:21:05 [scrapy.utils.log] INFO: Overridden settings: {'SPIDER_LOADER_WARN_ONLY': True}

# %% [markdown]
# les
# [extensions](https://docs.scrapy.org/en/latest/topics/extensions.html)
# ...:

# %%
2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled extensions:
['scrapy.extensions.corestats.CoreStats',
'scrapy.extensions.telnet.TelnetConsole',
'scrapy.extensions.logstats.LogStats']

# %% [markdown]
# [Les composants middleware
# downloader](https://docs.scrapy.org/en/latest/topics/downloader-middleware.html)
# ... :

# %%
2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled downloader middlewares:
['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
'scrapy.downloadermiddlewares.retry.RetryMiddleware',
'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
'scrapy.downloadermiddlewares.stats.DownloaderStats']

# %% [markdown]
# Idem pour [les composants middleware
# spider](https://docs.scrapy.org/en/latest/topics/spider-middleware.html)
# ...:

# %%
2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled spider middlewares:
['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
'scrapy.spidermiddlewares.referer.RefererMiddleware',
'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
'scrapy.spidermiddlewares.depth.DepthMiddleware']

# %% [markdown]
# Aucun
# [pipeline](https://docs.scrapy.org/en/latest/topics/item-pipeline.html)
# n'est activé :

# %%
2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled item pipelines:
[]

# %% [markdown]
# **Exercice**
#
# Identifier la position des [composants middleware
# downloader](https://docs.scrapy.org/en/latest/topics/downloader-middleware.html),
# des [composants middleware
# spider](https://docs.scrapy.org/en/latest/topics/spider-middleware.html)
# et du
# [pipeline](https://docs.scrapy.org/en/latest/topics/item-pipeline.html)
# dans $l'architecture <Introduction>$
#
# L'exécution du scraping proprement dit débute :

# %%
2018-01-10 17:21:05 [scrapy.core.engine] INFO: Spider opened
2018-01-10 17:21:05 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
2018-01-10 17:21:05 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023

# %% [markdown]
# La première URL est poussée par le scheduler:

# %%
2018-01-10 17:21:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)

# %% [markdown]
# ## Les résultats
#
# Les résultats sont fournis par le générateur défini dans la méthode
# $parse$ dans un dictionnaire. Ils contiennent le texte des citations
# dans la valeur de la clé `text` :

# %%
2018-01-10 17:21:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'text': '“Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.”'}
2018-01-10 17:21:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
{'text': "Faire le bien, éviter le mal, c'est ça le paradis."}

# %% [markdown]
# ## Les statistiques
#
# Une fois le scraping effectué, quelques statistiques sont affichées sur
# le terminal:

# %%
2018-01-10 17:21:05 [scrapy.core.engine] INFO: Closing spider (finished)
2018-01-10 17:21:05 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
{'downloader/request_bytes': 242,
'downloader/request_count': 1,
'downloader/request_method_count/GET': 1,
'downloader/response_bytes': 17435,
'downloader/response_count': 1,
'downloader/response_status_count/200': 1,
'finish_reason': 'finished',
'finish_time': datetime.datetime(2018, 1, 10, 16, 21, 5, 858347),
'item_scraped_count': 16,
'log_count/DEBUG': 18,
'log_count/INFO': 7,
'response_received_count': 1,
'scheduler/dequeued': 1,
'scheduler/dequeued/memory': 1,
'scheduler/enqueued': 1,
'scheduler/enqueued/memory': 1,
'start_time': datetime.datetime(2018, 1, 10, 16, 21, 5, 645347)}
2018-01-10 17:21:05 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On observe notamment que notre code permet de récupérer la taille de la
# page web (17435 bytes), le temps d'exécution à partir des valeurs
# `finish_time` et `start_time`, le nombre d'items scrapés (16), etc...
#
# **Exercice**
#
# Les citations extraites sont elles toutes de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill) ? Il sera
# peut être nécessaire de modifier le sélecteur XPath. Nous verrons ça
# lorsque il faudra récupérer les données relative à l'auteur.
#
# ## Modifier les données
#
# Il est parfois nécessaire de faire un traitement sur les données
# scrapées, pour ajouter ou retirer de l'information.
#
# **Exercice**
#
# Retirer les caractères `“` et `”` qui délimitent la citation. Ces
# caractères sont identifiés en Unicode comme [LEFT DOUBLE QUOTATION
# MARK](http://www.fileformat.info/info/unicode/char/201c/index.htm) et
# [RIGHT DOUBLE QUOTATION
# MARK](http://www.fileformat.info/info/unicode/char/201d/index.htm).
#
# ## Plus de données
#
# Il est souvent nécessaire de récupérer plusieurs informations relatives
# à un même item. Dans cet exemple, il est judicieux d'associer à la
# citation le nom de son auteur, en allant chercher cette information au
# plus près du texte lui même.
#
# **Exercice**
#
# Examiner le code source de la page web et identifier la structuration de
# la donnée associée à l'auteur. En déduire l'expression XPath permettant
# de la récupérer. S'assurer que seules les citations de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill) sont
# extraites. Ajouter une clé `author` au dictionnaire retourné par le
# $yield$ dont la valeur est précisément la chaîne de caractères contenant
# l'auteur.
#
# Un exemple de dictionnaire retourné:

# %%
{   'text': "“Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.”", 
    'author': 'Winston Churchill'}

# %% [markdown]
# Pour lancer l'exécution de la spider :
#
# > \$ scrapy runspider spiders/citations\_churchill\_spider2.py
#
# On peut aussi vouloir stocker les données extraites :
#
# > \$ scrapy runspider spiders/citations\_churchill\_spider2.py -o
# > data/citation.json -t json

# %% [markdown]
# # Votre premier projet
#
#
# Dans un premier temps vous devez créer un projet Scrapy avec la commande
# :

# %%
# !scrapy startproject newscrawler
# Out:
# New Scrapy project 'newscrawler', using template directory 'C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\templates\project', created in:
#     C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler
#
# You can start your first spider with:
#     cd newscrawler
#     scrapy genspider example example.com

# %% [markdown]
# Cette commande va créer un dossier `monprojet` contenant les éléments
# suivants correspondant au squelette :

# %%
newscrawler/
    scrapy.cfg            # Options de déploiement

    newscrawler/             # Le module Python contenant les informations
        __init__.py

        items.py          # Fichier contenant les items

        middlewares.py    # Fichier contenant les middlewares

        pipelines.py      # Fichier contenant les pipelines

        settings.py       # Fichier contenant les paramètres du projet

        spiders/          # Dossier contenant toutes les spiders
            __init__.py

# %% [markdown]
# # Votre première Spider
#
# Une Spider est une classe Scrapy qui permet de mettre en place toute
# l'architecture complexe vue dans l'introduction. Pour définir une
# spider, il vous faut hériter de la classe $scrapy.Spider$. La seule
# chose à faire est de définir la première requête à effectuer et comment
# suivre les liens. La Spider s'arrêtera lorsqu'elle aura parcouru tous
# les liens qu'on lui a demandé de suivre.
#
# Pour créer une Spider on utilise la syntaxe:

# %%
# !scrapy genspider AirParis airparif.asso.fr
# Out:
# Created spider 'AirParis' using template 'basic'

# %% [markdown]
# Par exemple,

# %%
# !cd newscrawler && scrapy genspider lemonde lemonde.fr
# Out:
# Created spider 'lemonde' using template 'basic' in module:
#   newscrawler.spiders.lemonde

# %% [markdown]
# Cette commande permet de créer une spider appelée `lemonde` pour scraper
# le domaine `lemonde.fr`. Cela crée le fichier Python
# `spiders/lemonde.py` suivant :

# %%
# %load newscrawler/newscrawler/spiders/lemonde.py
import scrapy


class LemondeSpider(scrapy.Spider):
    name = 'lemonde'
    allowed_domains = ['lemonde.fr']
    start_urls = ['http://lemonde.fr/']

    def parse(self, response):
        pass

# %% [markdown]
# Une bonne pratique pour commencer à développer une Spider est de passer
# par l'interface Shell proposée par Scrapy. Elle permet de récupérer un
# objet `Response` et de tester les méthodes de récupération des données.

# %% [markdown]
# # ATTENTION : Les commandes scrapy shell doivent être lancées dans un terminal

# %%
scrapy shell 'http://lemonde.fr'

# %% [markdown]
# Pour les utilisateurs de windows il vous faut mettre des doubles quotes
# :

# %%
scrapy shell "http://lemonde.fr"

# %% [markdown]
# Scrapy lance un kernel Python

# %%
2018-12-02 16:05:50 [scrapy.utils.log] INFO: Scrapy 1.3.3 started (bot: newscrawler)
2018-12-02 16:05:50 [scrapy.utils.log] INFO: Overridden settings: {'BOT_NAME': 'newscrawler', 'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter', 'LOGSTATS_INTERVAL': 0, 'NEWSPIDER_MODULE': 'newscrawler.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['newscrawler.spiders']}
2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled extensions:
['scrapy.extensions.corestats.CoreStats',
'scrapy.extensions.telnet.TelnetConsole']
2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled downloader middlewares:
['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
'scrapy.downloadermiddlewares.retry.RetryMiddleware',
'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
'scrapy.downloadermiddlewares.stats.DownloaderStats']
2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled spider middlewares:
['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
'scrapy.spidermiddlewares.referer.RefererMiddleware',
'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
'scrapy.spidermiddlewares.depth.DepthMiddleware']
2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled item pipelines:
[]
2018-12-02 16:05:50 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
2018-12-02 16:05:50 [scrapy.core.engine] INFO: Spider opened
2018-12-02 16:05:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
2018-12-02 16:05:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/> (referer: None)
2018-12-02 16:05:54 [traitlets] DEBUG: Using default logger
2018-12-02 16:05:54 [traitlets] DEBUG: Using default logger
[s] Available Scrapy objects:
[s]   scrapy     scrapy module (contains scrapy.Request, scrapy.Selector, etc)
[s]   crawler    <scrapy.crawler.Crawler object at 0x10fc38c18>
[s]   item       {}
[s]   request    <GET https://www.lemonde.fr/>
[s]   response   <200 https://www.lemonde.fr/>
[s]   settings   <scrapy.settings.Settings object at 0x113bb0898>
[s]   spider     <DefaultSpider 'default' at 0x113e60cc0>
[s] Useful shortcuts:
[s]   fetch(url[, redirect=True]) Fetch URL and update local objects (by default, redirects are followed)
[s]   fetch(req)                  Fetch a scrapy.Request and update local objects
[s]   shelp()           Shell help (print this help)
[s]   view(response)    View response in a browser

# %% [markdown]
# Grâce à cette interface, vous avez accès à plusieurs objets comme la
# `Response`, la `Request`, la `Spider` par exemple. Vous pouvez aussi
# exécuter `view(response)` pour afficher ce que Scrapy récupère dans un
# navigateur.

# %%
In [1]: response
Out[1]: <200 https://www.lemonde.fr/>

In [3]: request
Out[3]: <GET https://www.lemonde.fr/>

In [4]: type(request)
Out[4]: scrapy.http.request.Request

In [5]: spider
Out[5]: <LemondeSpider 'lemonde' at 0x1080fccc0>

In [6]: type(spider)
Out[6]: monprojet.spiders.lemonde.LeMondeSpider

# %% [markdown]
# Ici on voit que la Spider est une instance de LemondeSpider. Lorsqu'on
# lance le $scrapy shell$ scrapy va chercher dans les spiders si une
# correspond au lien passé en paramètre, si oui , il l'utilise sinon une
# $DefaultSpider$ est instanciée.
#
# ## Vos premières requêtes
#
# On peut commencer à regarder comment extraire les données de la page web
# en utilisant le langage de requêtes proposé par Scrapy. Il existe deux
# types de requêtes : les requêtes `css` et `xpath`. Les requêtes `xpath`
# sont plus complexes mais plus puissantes que les requêtes `css`. Dans le
# cadre de ce tutorial, nous allons uniquement aborder les requêtes `css`,
# elles nous suffiront pour extraire les données dont nous avons besoin
# (en interne, Scrapy transforme les requêtes `css`en requêtes `xpath`.
#
# Que ce soit les requêtes `css` ou `xpath`, elles crééent des sélecteurs
# de différents types. Quelques exemples :
#
# Pour récupérer le titre d'une page :

# %%
In [1]: response.css('title')
Out[1]: [<Selector xpath='descendant-or-self::title' data='<title>Le Monde.fr - Actualités et Infos'>]

# %% [markdown]
# On récupère une liste de sélecteurs correspondant à la requête `css`
# appelée. La requête précédente était unique, d'autres requêtes moins
# restrictives permettent de récupérer plusieurs résultats. Par exemple
# pour rechercher l'ensemble des liens présents sur la page, on va
# rechercher les balises HTML `<a></a>`

# %%
In [5]: response.css("a")[0:10]
Out[5]:
[<Selector xpath='descendant-or-self::a' data='<a target="_blank" data-target="jelec-he'>,
<Selector xpath='descendant-or-self::a' data='<a href="/"> <div class="logo__lemonde l'>,
<Selector xpath='descendant-or-self::a' data='<a href="https://secure.lemonde.fr/sfuse'>,
<Selector xpath='descendant-or-self::a' data='<a href="https://abo.lemonde.fr/#xtor=CS'>,
<Selector xpath='descendant-or-self::a' data='<a href="/" class="Burger__right-arrow j'>,
<Selector xpath='descendant-or-self::a' data='<a href="/" class="Burger__right-arrow j'>,
<Selector xpath='descendant-or-self::a' data='<a href="#" class="js-dropdown Burger__r'>,
<Selector xpath='descendant-or-self::a' data='<a href="/mouvement-des-gilets-jaunes/" '>,
<Selector xpath='descendant-or-self::a' data='<a href="/carlos-ghosn/" data-suggestion'>,
<Selector xpath='descendant-or-self::a' data='<a href="/implant-files/" data-suggestio'>]

# %% [markdown]
# Pour récupérer le texte contenu dans les balises, on passe le paramètre
# `<TAG>::text`. Par exemple :

# %%
In [6]: response.css("title::text")
Out[6]: [<Selector xpath='descendant-or-self::title/text()' data='Le Monde.fr - Actualités et Infos en Fra'>]

# %% [markdown]
# ### Exercice
#
#   Comparer les résultats des deux requêtes `response.css('title')` et
# `response.css('title::text')`.
#
# Maintenant pour extraire les données des selecteurs on utilise l'une des
# deux méthodes suivantes : - `extract()` permet de récupérer une liste
# des données extraites de tous les sélecteurs - `extract_first()` permet
# de récupérer une `String` provenant du premier sélecteur de la liste.

# %%
In [7]: response.css('title::text').extract_first()
Out[7]: 'Le Monde.fr - Actualités et Infos en France et dans le monde'

# %% [markdown]
# On peut récupérer un attribut d'une balise avec la syntaxe
# `<TAG>::attr(<ATTRIBUTE_NAME>)` :
#
# Par exemple, les liens sont contenus dans un attribut `href`.

# %%
In [9]: response.css('a::attr(href)')[0:10]
Out[9]:
[<Selector xpath='descendant-or-self::a/@href' data='https://journal.lemonde.fr'>,
<Selector xpath='descendant-or-self::a/@href' data='/'>,
<Selector xpath='descendant-or-self::a/@href' data='https://secure.lemonde.fr/sfuser/connexi'>,
<Selector xpath='descendant-or-self::a/@href' data='https://abo.lemonde.fr/#xtor=CS1-454[CTA'>,
<Selector xpath='descendant-or-self::a/@href' data='/'>,
<Selector xpath='descendant-or-self::a/@href' data='/'>,
<Selector xpath='descendant-or-self::a/@href' data='#'>,
<Selector xpath='descendant-or-self::a/@href' data='/mouvement-des-gilets-jaunes/'>,
<Selector xpath='descendant-or-self::a/@href' data='/carlos-ghosn/'>,
<Selector xpath='descendant-or-self::a/@href' data='/implant-files/'>]

# %% [markdown]
# Comme vu précédemment, si on veut récupérer la liste des liens de la page on applique la méthode $extract()$

# %%
In [11]: response.css('a::attr(href)').extract()[0:10]
Out[11]:
['https://journal.lemonde.fr',
'/',
'https://secure.lemonde.fr/sfuser/connexion',
'https://abo.lemonde.fr/#xtor=CS1-454[CTA_LMFR]-[HEADER]-5-[Home]',
'/',
'/',
'#',
'/mouvement-des-gilets-jaunes/',
'/carlos-ghosn/',
'/implant-files/']

# %% [markdown]
# Les liens dans une page HTML sont souvent codés de manière relative par
# rapport à la page courante. La méthode de l'objet `Response` peut être
# utilisée pour recréer l'url complet.
#
# Un exemple sur le 4e élément :

# %%
In [14]: response.urljoin(response.css('a::attr(href)').extract()[8])
Out[14]: 'https://www.lemonde.fr/carlos-ghosn/'

# %% [markdown]
# alors que

# %%
In [15]: response.css('a::attr(href)').extract()[8]
Out[15]: '/carlos-ghosn/'

# %% [markdown]
# ### Exercice :
#
# Utiliser une liste compréhension pour transformer les 10
# premiers liens relatifs récupérés par la méthode `extract()` en liens
# absolus.
#
# Le résultat doit ressembler à :

# %%
Out[23]: 
['https://journal.lemonde.fr',
'https://www.lemonde.fr/',
'https://secure.lemonde.fr/sfuser/connexion',
'https://abo.lemonde.fr/#xtor=CS1-454[CTA_LMFR]-[HEADER]-5-[Home]',
'https://www.lemonde.fr/',
'https://www.lemonde.fr/',
'https://www.lemonde.fr/',
'https://www.lemonde.fr/mouvement-des-gilets-jaunes/',
'https://www.lemonde.fr/carlos-ghosn/',
'https://www.lemonde.fr/implant-files/']

# %% [markdown]
# ## Des requêtes plus complexes
#
# On peut créer des requêtes plus complexes en utilisant à la fois la
# structuration HTML du document mais également la couche de présentation
# CSS. On utilise l'inspecteur de `Google Chrome` pour identifier le type
# et l'identifiant de la balise contenant les informations.
#
# Il y a au moins deux choses à savoir en `css` :
#
# -   Les `.` représentent les classes
# -   Les `#` représentent les id
#
# On se propose de récupérer toutes les sous-catégories de news dans la
# catégorie **Actualités**. On remarque en utilisant l'inspecteur
# d'élement de Chrome que toutes les catégories sont rangées dans une
# balise avec l'id $#nav-markup$ ensuite dans les classes $Nav__item$.
#
# A partir de cette structure HTML on peut construire la requête suivante
# pour récupérer la barre de navigation:

# %%
In [19]: response.css("#nav-markup")
Out[19]: [<Selector xpath="descendant-or-self::*[@id = 'nav-markup']" data='<ul id="nav-markup"> <li class="Nav__ite'>]

# %% [markdown]
# Ensuite pour récupérer les différentes catégories :

# %%
In [24]: response.css("#nav-markup .Nav__item")
Out[24]:
[<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item js-burger-to-show N'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--home Nav'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="/" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="/recherc'>]

# %% [markdown]
# On veut maintenant retourner tous les liens présents dans cette
# catégorie. On remarque qu'elle apparait à la 4eme position.

# %%
In [34]: response.css("#nav-markup .Nav__item")[3]
Out[34]: <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>

# %% [markdown]
# Maintenant pour récupérer tous les liens on peut chainer les requêtes.
# On accède alors à toutes les balises $a$.

# %%
In [35]: response.css("#nav-markup .Nav__item")[3].css("a")
Out[35]:
[<Selector xpath='descendant-or-self::a' data='<a href="#" class="js-dropdown Burger__r'>,
<Selector xpath='descendant-or-self::a' data='<a href="/mouvement-des-gilets-jaunes/" '>,
<Selector xpath='descendant-or-self::a' data='<a href="/carlos-ghosn/" data-suggestion'>,
<Selector xpath='descendant-or-self::a' data='<a href="/implant-files/" data-suggestio'>,
<Selector xpath='descendant-or-self::a' data='<a href="/climat/" data-suggestion>Clima'>,
<Selector xpath='descendant-or-self::a' data='<a href="/affaire-khashoggi/" data-sugge'>,
<Selector xpath='descendant-or-self::a' data='<a href="/emmanuel-macron/" data-suggest'>,
<Selector xpath='descendant-or-self::a' data='<a href="/ukraine/" data-suggestion>Ukra'>,
<Selector xpath='descendant-or-self::a' data='<a href="/russie/" data-suggestion>Russi'>,
<Selector xpath='descendant-or-self::a' data='<a href="/referendum-sur-le-brexit/" dat'>,
<Selector xpath='descendant-or-self::a' data='<a href="/harcelement-sexuel/" data-sugg'>,
<Selector xpath='descendant-or-self::a' data='<a href="/actualite-en-continu/" data-su'>,
<Selector xpath='descendant-or-self::a' data='<a href="/international/">International<'>,
<Selector xpath='descendant-or-self::a' data='<a href="/politique/">Politique</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/societe/">Société</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/les-decodeurs/">Les Décodeurs<'>,
<Selector xpath='descendant-or-self::a' data='<a href="/sport/">Sport</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/planete/">Planète</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/sciences/">Sciences</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/campus/">M Campus</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/afrique/">Le Monde Afrique</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/pixels/">Pixels</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/actualite-medias/">Médias</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/sante/">Santé</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/big-browser/">Big Browser</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/disparitions/">Disparitions</a'>]

# %% [markdown]
# Et pour récupérer les titres :

# %%
In [37]: response.css("#nav-markup .Nav__item")[3].css("a::text").extract()
Out[37]:
['Actualités',
'Mouvement des "gilets jaunes"',
'Carlos Ghosn',
'Implant Files',
'Climat',
'Affaire Khashoggi',
'Emmanuel Macron',
'Ukraine',
'Russie',
'Brexit',
'Harcèlement sexuel',
'Toute l’actualité en continu',
'International',
'Politique',
'Société',
'Les Décodeurs',
'Sport',
'Planète',
'Sciences',
'M Campus',
'Le Monde Afrique',
'Pixels',
'Médias',
'Santé',
'Big Browser',
'Disparitions']

# %% [markdown]
# Le shell Scrapy permet de définir la structure des requêtes et de
# s'assurer de la pertinence du résultat retourné. Pour automatiser le
# processus, il faut intégrer cette syntaxe au code Python des modules de
# spider définis dans la structure du projet.
#
# ## Intégration des requêtes
#
# Le squelette de la classe `LeMondeSpider` généré lors de la création du
# projet doit maintenant être enrichi. Par défaut 3 attributs et une
# méthode `parse()` ont été créés :
#
# -   `name` permet d'identifier sans ambiguïté la spider dans le code.
# -   `allowed_domain` permet de filtrer les requêtes et forcer la spider
#     à rester sur une liste de domaines.
# -   `starts_urls` est la liste des urls d'où la spider va partir pour
#     commencer son scraping.
# -   `parse()` est une méthode héritée de la classe `scrapy.Spider`. Elle
#     doit être redéfinie selon les requêtes que l'on doit effectuer et
#     sera appelée sur l'ensemble des urls contenus dans la liste
#     `starts_urls`.
#
# `parse()` est une fonction `callback` qui sera appelée automatiquement
# sur chaque objet `Response` retourné par la requête. Cette fonction est
# appelée de manière asynchrone. Plusieurs requêtes peuvent ainsi être
# lancées en parallèles sans bloquer le thread principal. L'objet
# `Response` passé en paramètre est le même que celui mis à disposition
# lors de l'exécution du Scrapy Shell.

# %%
def parse(self, response):
    title = response.css('title::text').extract_first()
    all_links = {
        name:response.urljoin(url) for name, url in zip(
        response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
        response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
    }
    yield {
        "title":title,
        "all_links":all_links
    }

# %% [markdown]
# La fonction est un générateur (`yield`) et retourne un dictionnaire
# composé de deux éléments :
#
# -   Le titre de la page;
# -   La liste des liens sortants sous forme de String.
#
# Pour le moment cette spider ne parcourt que la page d'accueil, ce qui
# n'est pas très productif.
#
# ## Votre premier scraper
#
# Récupérer les données sur un ensemble de pages webs nécessite d'explorer
# en profondeur la structure du site en suivant tout ou partie des liens
# rencontrés.
#
# La spider peut se `balader` sur un site assez efficacement. Il suffit de
# lui indiquer comment faire. Il faut spécifier à Scrapy de générer une
# requête vers une nouvelle page en construisant l'objet `Request`
# correspondant. Ce nouvel objet `Request` est alors inséré dans le
# scheduler de Scrapy. On peut évidemment générer plusieurs `Request`
# simultanément, correspondant par exemple, à différents liens sur la page
# courante. Ils sont insérés séquentiellement dans le scheduler.
#
# Pour cela on modifie la méthode `parse()` de façon à ce qu'elle retourne
# un objet `Request` pour chaque nouveau lien rencontré. On associe
# également à cet objet une fonction de callback qui déterminera la
# manière dont cette nouvelle page doit être extraite.
#
# Par exemple, pour que la spider continue dans les liens des différentes
# régions (pour l'instant la fonction de callback ne fait rien) :

# %%
# %load newscrawler/newscrawler/spiders/lemonde_v2.py
import scrapy
from scrapy import Request


class LemondeSpider(scrapy.Spider):
    name = "lemondev2"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name:response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        yield {
            "title":title,
            "all_links":all_links
        }

# %% [markdown]
# Pour lancer la spider

# %%
# !cd newscrawler && scrapy crawl lemondev2
# Out:
# 2023-11-28 15:08:11 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-11-28 15:08:11 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22631-SP0
# 2023-11-28 15:08:11 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-28 15:08:11 [asyncio] DEBUG: Using selector: SelectSelector
# 2023-11-28 15:08:11 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-11-28 15:08:11 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2023-11-28 15:08:11 [scrapy.extensions.telnet] INFO: Telnet Password: 574fa1b6950020b0
# 2023-11-28 15:08:11 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-28 15:08:11 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-11-28 15:08:11 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-28 15:08:11 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-28 15:08:11 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-28 15:08:11 [scrapy.core.engine] INFO: Spider opened
# 2023-11-28 15:08:11 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-28 15:08:11 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2023-11-28 15:08:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-11-28 15:08:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2023-11-28 15:08:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr>
#
# {'title': 'Le Monde.fr - Actualités et Infos en France et dans le monde', 'all_links': {'Actualités': 'https://www.lemonde.fr', 'Guerre Israël-Hamas': 'https://www.lemonde.fr/attaque-du-hamas-contre-israel/', 'Guerre en Ukraine': 'https://www.lemonde.fr/crise-ukrainienne/', 'Antisémitisme': 'https://www.lemonde.fr/antisemitisme/', "Procès d'Éric Dupond-Moretti": 'https://www.lemonde.fr/proces-eric-dupond-moretti/', 'Immigration et diversité': 'https://www.lemonde.fr/immigration-et-diversite/', 'Jeux olympiques de Paris 2024': 'https://www.lemonde.fr/jeux-olympiques-2024/', 'Tempêtes et ouragans': 'https://www.lemonde.fr/ouragans/', 'Inflation': 'https://www.lemonde.fr/inflation/', 'Chine': 'https://www.lemonde.fr/chine/', 'Toute l’actualité en continu': 'https://www.lemonde.fr/actualite-en-continu/', 'International': 'https://www.lemonde.fr/international/', 'Politique': 'https://www.lemonde.fr/politique/', 'Société': 'https://www.lemonde.fr/societe/', 'Planète': 'https://www.lemonde.fr/planete/', 'Climat': 'https://www.lemonde.fr/climat/', 'Le Monde Afrique': 'https://www.lemonde.fr/afrique/', 'Les Décodeurs': 'https://www.lemonde.fr/les-decodeurs/', 'Sport': 'https://www.lemonde.fr/sport/', 'Education': 'https://www.lemonde.fr/education/', 'M Campus': 'https://www.lemonde.fr/campus/', 'Santé': 'https://www.lemonde.fr/sante/', 'Intimités': 'https://www.lemonde.fr/intimites/', 'Sciences': 'https://www.lemonde.fr/sciences/', 'Pixels': 'https://www.lemonde.fr/pixels/', 'Disparitions': 'https://www.lemonde.fr/disparitions/', 'Le Fil Good': 'https://www.lemonde.fr/le-fil-good/', 'Podcasts': 'https://www.lemonde.fr/podcasts/', 'Le Monde & Vous': 'https://www.lemonde.fr/le-monde-et-vous/'}}
# 2023-11-28 15:08:12 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-28 15:08:12 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 440,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 80553,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 0.848175,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 28, 14, 8, 12, 349987, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 295886,
#  'httpcompression/response_count': 2,
#  'item_scraped_count': 1,
#  'log_count/DEBUG': 6,
#  'log_count/INFO': 10,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 11, 28, 14, 8, 11, 501812, tzinfo=datetime.timezone.utc)}
# 2023-11-28 15:08:12 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On veut ensuite *entrer* dans les liens des différentes sous-catégories
# pour récupérer les articles. Pour cela, nous créons une méthode
# `parse_category()` prend en argument un objet `Response` qui sera la
# réponse correspondant aux liens des régions. On peut comme ceci
# traverser un site en définissant des méthodes différentes en fonction du
# type de contenu.
#
# Si la structure du site est plus profonde, on peut empiler autant de
# couches que souhaité.
#
# Quand on arrive sur une page d'une sous-catégorie, on peut vouloir
# récupérer tous les éléments de la page. Pour cela, on réutilise le
# scrapy Shell pour commencer le développement de la nouvelle méthode
# d'extraction.
#
# Par exemple pour la page `https://www.lemonde.fr/international/` :

# %%
scrapy shell 'https://www.lemonde.fr/international/'

# %% [markdown]
# Le fil des articles est stocké dans une balise avec la classe
# `class=river`.

# %%
In [3]: response.css(".river")
Out[3]:
[<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' fleuve ')]" data='<div class="fleuve">\n   <section>\n      '>,
<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' fleuve ')]" data='<div class="fleuve">\n</div>'>]

# %% [markdown]
# Pour récupérer chacun des articles, il faut adresser les balises
# `<article>` contenues dans le sélecteur:

# %%
In [4]: response.css(".river")[0].css(".teaser")
Out[4]:
[<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi mg'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>]

# %% [markdown]
# Comme précédemment, on peut empiler les sélecteurs `css` pour créer des
# requêtes plus complexes.
#
# Par exemple, pour récupérer tous les titres des différents articles :

# %%
In [8]: response.css(".river")[0].css(".teaser h3::text").extract()
Out[8]:
['Des dizaines de milliers de Géorgiens contestent dans la rue l’élection de Salomé Zourabichvili\r\n\r\n\r\n',
'A Budapest en Hongrie, un îlot décroissant pour favoriser la transition\r\n\r\n\r\n',
'En Israël, la police recommande l’inculpation de Nétanyahou dans une troisième enquête\r\n\r\n\r\n',
'Donald Trump veut «\xa0mettre fin\xa0» à l’Aléna rapidement\r\n\r\n\r\n',
'Le cauchemar de la «\xa0rééducation\xa0» des musulmans en Chine\r\n\r\n',
'\r\n',
'«\xa0AMLO\xa0» lance sa transformation du Mexique\r\n\r\n\r\n',
'«\xa0Paris brûle\xa0»\xa0: les médias étrangers relatent le «\xa0chaos\xa0» en marge des défilés des «\xa0gilets jaunes\xa0»\r\n\r\n\r\n',
'Andrés Manuel Lopez Obrador intronisé président du Mexique\r\n\r\n\r\n']

# %% [markdown]
# En HTML les données sont souvent de très mauvaise qualité. Il faut
# définir des méthodes permettant de les nettoyer pour être intégrées dans
# des bases de données.
#
# Par exemple, pour supprimer tous les espaces superflus :

# %%
def clean_spaces(string_):
    if string_ is not None: 
        return " ".join(string_.split())

# %% [markdown]
# Pour l'appliquer à tous les titres récupérés, on peut faire une list
# comprehension :

# %%
In [11]: [clean_spaces(article) for article in response.css(".river")[0].css(".teaser h3::text").extract()]  

Out[11]: ['Des dizaines de milliers de Géorgiens contestent dans la rue l’élection de Salomé Zourabichvili',
          'A Budapest en Hongrie, un îlot décroissant pour favoriser la transition', 
          'En Israël, la police recommande l’inculpation de Nétanyahou dans une troisième enquête',
          'Donald Trump veut « mettre fin » à l’Aléna rapidement', 
          'Le cauchemar de la « rééducation » des musulmans en Chine',
          '',
          '« AMLO » lance sa transformation du Mexique', 
          '« Paris brûle » : les médias étrangers relatent le « chaos » en marge des défilés des « gilets jaunes »',
          'Andrés Manuel Lopez Obrador intronisé président du Mexique'
         ]

# %% [markdown]
# La méthode précédente est intéressante si l'on ne recherche qu'une seule
# information par article.
#
# Par contre si l'on veut récupérer d'autres caractéristiques comme
# l'image ou la description par exemple, il est plus intéressant et plus
# efficace de récupérer l'objet et d'effectuer plusieurs traitements sur
# ce dernier.
#
# Chaque objet retourné par les requêtes `css` est un selecteur avec
# lequel on peut interagir.
#
# Par exemple pour récupérer le titre et le prix

# %%
In [25]: for article in response.css(".fleuve")[0].css("article"):
...:     title = clean_spaces(article.css("h3 a::text").extract_first())
...:     image = article.css("img::attr(data-src)").extract_first()
...:     description = article.css(".txt3::text").extract_first()
...:     print(f"Title {title} \nImage {image}\nDescription {description}\n ----")

# %%
Title Des dizaines de milliers de Géorgiens contestent dans la rue l’élection de Salomé Zourabichvili
Image https://s1.lemde.fr/image/2018/12/02/147x97/5391641_7_5874_les-partisans-de-l-opposant-grigol-vashadze_20d2e8693a49b83fd3c5578f7799ae9c.jpg
Description Elue présidente (un rôle essentiellement symbolique en Géorgie), l’ex-diplomate française, candidate du pouvoir, est contestée par l’opposition.
----
Title A Budapest en Hongrie, un îlot décroissant pour favoriser la transition
Image https://img.lemde.fr/2018/12/01/10/0/4214/2809/147/97/60/0/15b32ca_1EY4qISQ_BP4kPAh1fozJdXZ.jpg
Description Le centre logistique Cargonomia sert de matrice aux coopératives de l’économie durable et solidaire hongroise.
----
Title En Israël, la police recommande l’inculpation de Nétanyahou dans une troisième enquête
Image https://img.lemde.fr/2018/12/02/167/0/4207/2804/147/97/60/0/9e02c9b_3580d043ebc94b48b0f2cfef4e9a21e7-3580d043ebc94b48b0f2cfef4e9a21e7-0.jpg
Description Le premier ministre est soupçonné de corruption, fraude et abus de pouvoir, dans une affaire impliquant le groupe de télécoms israélien Bezeq.
----
Title Donald Trump veut « mettre fin » à l’Aléna rapidement
Image https://img.lemde.fr/2018/11/30/0/0/4861/3240/147/97/60/0/8b87184_5826023-01-06.jpg
Description Le président américain souhaite voir disparaître l’accord de libre-échange remontant à 1994 avec le Mexique et le Canada, qu’il qualifie régulièrement de « pire accord jamais signé », en faveur du nouveau traité négocié difficilement avec ses voisins nord-américains ces derniers mois.
----
Title Le cauchemar de la « rééducation » des musulmans en Chine
Image https://img.lemde.fr/2018/11/15/151/0/5000/3333/147/97/60/0/118c78f_248b226e6b91450aa8a68bd0ea5525a8-248b226e6b91450aa8a68bd0ea5525a8-0.jpg
Description Ouïgours et Kazakhs du Xinjiang... C’est toute une population musulmane que Pékin veut « rééduquer » en internant des centaines de milliers d’entre eux dans des camps.
----
Title « AMLO » lance sa transformation du Mexique
Image https://img.lemde.fr/2018/12/02/45/0/1497/998/147/97/60/0/a33c174_GGGTBR84_MEXICO-POLITICS-_1202_11.JPG
Description Education et santé gratuites, hausse du salaire minimum, bourses scolaires : à peine investi, le président Andres Manuel Lopez Obrador a listé les mesures qu’il entend prendre pour redresser le pays.
----
Title « Paris brûle » : les médias étrangers relatent le « chaos » en marge des défilés des « gilets jaunes »
Image https://img.lemde.fr/2018/12/02/361/0/598/396/147/97/60/0/ba46a6e_XVIt1Ffwm50iYBheccVieUQQ.jpg
Description Les images de destructions, d’échauffourées ou de voitures enflammées s’affichaient samedi soir en « une » de nombreux sites d’actualité internationaux.
----
Title Andrés Manuel Lopez Obrador intronisé président du Mexique
Image https://img.lemde.fr/2018/12/02/91/145/1346/897/147/97/60/0/877cd51_a4618baa8da2414bb62bab28a6d4c745-a4618baa8da2414bb62bab28a6d4c745-0.jpg
Description Le nouveau chef d’Etat a promis de lutter contre la corruption en menant une transformation « profonde et radicale » du pays.
----

# %% [markdown]
# ## Persistence des données
#
# Pour pouvoir stocker les informations que l'on récupère en parcourant un
# site il faut pouvoir les stocker. On utilise soit de simples
# dictionnaires Python, ou mieux des `scrapy.Item` qui sont des
# dictionnaires améliorés.
#
# Nous allons voir les deux façons de faire. On peut réécrire la méthode
# `parse_category()` pour lui faire retourner un dictionnaire
# correspondant à chaque offre rencontrée.

# %%
def parse_category(self, response):
    for article in response.css(".fleuve")[0].css("article"):
        title = self.clean_spaces(article.css("h3 a::text").extract_first())
        image = article.css("img::attr(data-src)").extract_first()
        description = article.css(".txt3::text").extract_first()
        yield {
            "title":title,
            "image":image,
            "description":description
        }

# %% [markdown]
# Si on combine tout dans la spider :

# %%
# %load newscrawler/newscrawler/spiders/lemonde_v3.py
import scrapy
from scrapy import Request


class LemondeSpider(scrapy.Spider):
    name = "lemondev3"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name:response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        for link in all_links.values():
            yield Request(link, callback=self.parse_category)
            
    def parse_category(self, response):
        for article in response.css(".river")[0].css(".teaser"):
            title = self.clean_spaces(article.css("h3::text").extract_first())
            image = article.css("img::attr(data-src)").extract_first()
            description = article.css(".txt3::text").extract_first()
            yield {
                "title":title,
                "image":image,
                "description":description
            }

    def clean_spaces(self, string):
        if string:
            return " ".join(string.split())

# %% [markdown]
# On peut maintenant lancer notre spider avec la commande suivante :

# %%
scrapy crawl <NAME>

# %% [markdown]
# `scrapy crawl` permet de démarrer le processus en allant chercher la
# classe `scrapy.Spider` dont l'attribut `name` = &lt;NAME&gt;.
#
# Par exemple, pour la spider `LeMondeSpider` :

# %%
# !cd newscrawler && scrapy crawl lemondev3
# Out:
# 2023-11-28 15:48:03 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-11-28 15:48:03 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22631-SP0
# 2023-11-28 15:48:03 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-28 15:48:03 [asyncio] DEBUG: Using selector: SelectSelector
# 2023-11-28 15:48:03 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-11-28 15:48:03 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2023-11-28 15:48:03 [scrapy.extensions.telnet] INFO: Telnet Password: 03e437167740ba58
# 2023-11-28 15:48:03 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-28 15:48:03 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-11-28 15:48:03 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-28 15:48:03 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-28 15:48:03 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-28 15:48:03 [scrapy.core.engine] INFO: Spider opened
# 2023-11-28 15:48:03 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-28 15:48:03 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2023-11-28 15:48:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-11-28 15:48:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2023-11-28 15:48:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# 2023-11-28 15:48:06 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 22, in parse_category
#     for article in response.css(".river")[0].css(".teaser"):
#                    ~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 15:48:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sante/> (referer: https://www.lemonde.fr)
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Agnès Buzyn : « Qui peut penser qu’un hypothétique refus de soins décourage l’immigration clandestine ? »', 'image': 'https://img.lemde.fr/2023/11/26/0/0/4999/3333/110/73/60/0/9f2c74b_1701027084021-ad027necker-dsc02575.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Tabagisme : « Il faut avancer sur la voie de la réduction des risques »', 'image': 'https://img.lemde.fr/2023/04/27/0/0/4253/2835/110/73/60/0/a40be1e_1682585330590-2d85c17-1680106845701-le-monde-tribune-def-01.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Narcotrafic : devant le Sénat, le portrait d’une France où « aucun territoire n’est épargné »', 'image': 'https://img.lemde.fr/2023/11/28/0/0/5722/3814/110/73/60/0/3b1a4e5_1701167982825-953661.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Hausse modérée du prix des cigarettes, plus de lieux publics sans tabac, interdiction des puffs : le gouvernement présente son plan contre le tabagisme', 'image': 'https://img.lemde.fr/2023/11/17/0/0/5860/3906/110/73/60/0/5b10d1d_1700234764531-940190.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Les Assises de la pédiatrie, attendues depuis un an, désormais annoncées pour janvier', 'image': 'https://img.lemde.fr/2023/11/27/0/0/4644/3096/110/73/60/0/cda3db3_1701067752039-000-336c2ep.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Que sait-on du travail ? » : des pistes de soutenabilité pour travailler à tout âge', 'image': 'https://img.lemde.fr/2023/11/24/0/139/832/555/110/73/60/0/450c6ec_1700845387440-media-appel-soutenabilite-travail-3x.png', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'A l’hôpital Necker-Enfants malades, temple de l’excellence de la pédiatrie à l’épreuve de la crise', 'image': 'https://img.lemde.fr/2023/11/26/0/0/4999/3333/110/73/60/0/8e51232_1701026946389-ad008necker-dsc02502.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Les Français fument bien plus que leurs voisins, même si le prix de leurs cigarettes est jusqu’à deux fois plus onéreux »', 'image': 'https://img.lemde.fr/2023/11/24/517/0/3100/2066/110/73/60/0/314c407_1700817522253-pns-4683842.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Accouchement à domicile : un drame relance le débat entre soignants', 'image': 'https://img.lemde.fr/2023/11/24/230/0/1654/1102/110/73/60/0/c9bc881_1700868388944-2023-11-24-colcanopa.jpeg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Les pneumopathies infantiles connaissent une forte recrudescence en France', 'image': 'https://img.lemde.fr/2023/11/25/0/0/6000/4000/110/73/60/0/6542660_1700902652239-000-32v7277.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'La PMA, un parcours du combattant ?', 'image': 'https://img.lemde.fr/2023/10/31/500/0/3001/2000/110/73/60/0/6b5ce3e_1698743727754-4.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Violences conjugales : les professionnels de santé questionnent trop peu leurs patientes, selon la Haute Autorité de santé', 'image': 'https://img.lemde.fr/2023/11/22/1/0/6000/4000/110/73/60/0/9756064_5941042-01-06.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Psychiatre est un métier d’engagement, de valeurs, de passion et pourtant méconnu »', 'image': 'https://img.lemde.fr/2023/04/27/0/0/4253/2835/110/73/60/0/a40be1e_1682585330590-2d85c17-1680106845701-le-monde-tribune-def-01.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Vaccination contre le papillomavirus : pas de « dysfonctionnement » identifié après la mort d’un collégien', 'image': 'https://img.lemde.fr/2023/11/24/0/0/664/442/110/73/60/0/241e627_1700821729925-25daa07-1692200901929-epa-10665477.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Dans le nord de la Chine, les hôpitaux débordés par une flambée de cas de maladies respiratoires', 'image': 'https://img.lemde.fr/2023/11/23/0/6/5503/3669/110/73/60/0/3c3295b_1700753795243-977983.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Pourquoi une nouvelle loi sur la fin de vie ? Comprendre en trois minutes', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1023/682/110/73/60/0/4c73d15_1700586786323-000-336g9u2.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Pourquoi le sport devrait être remboursé comme un médicament', 'image': 'https://img.lemde.fr/2023/10/13/0/0/1800/1200/110/73/60/0/fcaa0e1_1697197668043-sport.png', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Flambée de maladies respiratoires : la Chine ne signale « aucun pathogène nouveau ou inhabituel », selon l’OMS', 'image': 'https://img.lemde.fr/2023/11/23/0/6/5851/3901/110/73/60/0/afc231d_5950106-01-06.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Bien vieillir » : « Les vieux méritent mieux qu’un empilement de mesurettes »', 'image': 'https://img.lemde.fr/2023/11/22/0/0/5000/3333/110/73/60/0/211de03_1700664550821-pns-6741041.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'L’Organisation mondiale de la santé s’inquiète d’une hausse des maladies respiratoires en Chine', 'image': 'https://img.lemde.fr/2023/01/19/0/0/4000/2666/110/73/60/0/6095dda_5247753-01-06.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Supprimer l’aide médicale d’Etat serait une faute grave »', 'image': 'https://img.lemde.fr/2023/11/14/0/0/5410/3607/110/73/60/0/63be61d_5872065-01-06.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Trafic de drogue et d’armes : procès requis contre d’importants trafiquants de Saint-Ouen', 'image': 'https://img.lemde.fr/2023/11/21/0/0/8256/5504/110/73/60/0/2fc5b07_1700583031891-ad43d87-1694187639971-000-33mg2hg.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Paludisme : la vaccination à grande échelle en Afrique « va bientôt commencer », affirme l’Alliance du vaccin', 'image': 'https://img.lemde.fr/2023/11/22/729/819/4467/2978/110/73/60/0/d81f3a0_1700663155898-000-33ar69z.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Déserts médicaux : l’UFC-Que choisir attaque l’Etat en justice pour « inaction »', 'image': 'https://img.lemde.fr/2023/05/23/0/0/5733/3822/110/73/60/0/aade3c3_1684846729586-pns-4090142.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'L’ordre des médecins exprime « sa profonde inquiétude » sur le projet d’installation d’espaces de télémédecine dans les gares SNCF', 'image': 'https://img.lemde.fr/2019/10/22/0/128/4543/3029/110/73/60/0/230d9ac_LR249d0s4052-Jt8rN9dMidB.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Loi « bien vieillir » : les députés adoptent des propositions pour le grand âge mais demandent des « moyens »', 'image': 'https://img.lemde.fr/2023/07/20/0/0/4387/2924/110/73/60/0/69714fa_1689868918566-abacanewsroy-861217-008.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Abandons de poste : entre faux licenciement et vraie démission, le flou juridique demeure', 'image': 'https://img.lemde.fr/2023/11/20/1039/0/3778/2518/110/73/60/0/fc145dd_1700490463083-pns-5651568.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Ces vingtenaires qui se détournent de l’alcool : « Tu as l’impression que c’est un anxiolytique rapide, mais, le lendemain, tu doubles ton angoisse »', 'image': 'https://img.lemde.fr/2023/11/20/90/0/7543/5028/110/73/60/0/95c0deb_1700474360004-sobriei-tei-clr.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Les pharmaciens alertent sur le malaise de l’officine', 'image': 'https://img.lemde.fr/2023/11/20/0/0/5439/3626/110/73/60/0/3e91b03_1700463729972-000-32lp7vb.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'La députée Sandrine Josso veut sensibiliser au « fléau » de la soumission chimique après avoir été droguée à son insu', 'image': 'https://img.lemde.fr/2023/11/20/0/0/4828/3219/110/73/60/0/9f14962_1700511004161-000-33y33gm.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'La proposition de loi « bien vieillir » revient à l’Assemblée avec la promesse d’une loi de programmation sur le grand âge', 'image': 'https://img.lemde.fr/2023/11/20/1/0/8192/5461/110/73/60/0/bf77199_1700463152513-943741.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Soigner ou ne pas soigner ? Dans les coulisses du Centre d’éthique clinique de l’AP-HP', 'image': 'https://img.lemde.fr/2023/11/18/0/0/2125/1417/110/73/60/0/4e3075d_1700299539461-le-monde-comite-ethique-hd.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Travailleurs du soin, unissons-nous contre la suppression programmée de l’aide médicale d’Etat »', 'image': 'https://img.lemde.fr/2022/12/19/0/0/2500/1666/110/73/60/0/0c3d6a7_1671491838785-eleonora-strano-covid-nice-fin2020-20.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Assurance santé : puis-je garder ma mutuelle d’entreprise à la retraite ?', 'image': 'https://img.lemde.fr/2023/04/18/0/0/3000/2000/110/73/60/0/a61890c_1681830091357-hjuy.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Comment le ministre de la santé, Aurélien Rousseau, tente d’imprimer sa marque', 'image': 'https://img.lemde.fr/2023/11/17/0/0/6328/4219/110/73/60/0/6e3e30f_1700234567165-940271.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Les « patients partenaires », quand les malades du cancer deviennent experts', 'image': 'https://img.lemde.fr/2023/11/16/212/0/3500/2333/110/73/60/0/9127c10_1700128162636-pink-vill0331513.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Prévention : les « bilans » de santé aux âges-clés de la vie se font attendre', 'image': 'https://img.lemde.fr/2023/11/17/0/0/5860/3906/110/73/60/0/5b10d1d_1700234764531-940190.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'De nouvelles pistes de traitement contre la tuberculose', 'image': 'https://img.lemde.fr/2023/11/17/0/34/4380/2920/110/73/60/0/b18ccac_1700239273625-000-13e35c.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Quand on n’arrive pas à faire un bébé, on fait quoi ?', 'image': 'https://img.lemde.fr/2023/10/30/72/0/3004/2002/110/73/60/0/874c3ca_1698676158545-3.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Cancer : le temps des témoignages, sur les réseaux, sur scène ou dans des podcasts', 'image': 'https://img.lemde.fr/2023/11/03/136/133/3341/2227/110/73/60/0/4a3bfd6_1699029585419-patients-partenaires-2.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Face à la résistance aux antibiotiques, la France présente une évolution contrastée', 'image': 'https://img.lemde.fr/2023/11/17/269/279/4365/2910/110/73/60/0/6677a17_1700240333143-000-1qf31a.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Déserts médicaux : la SNCF annonce l’installation de centres de télémédecine dans environ 300 gares', 'image': 'https://img.lemde.fr/2016/05/29/0/0/5184/3456/110/73/60/0/2c9e0d0_5962920-01-06.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« La décision du Sénat de supprimer l’AME ne correspond à aucune logique médicale, budgétaire ou de lutte contre la fraude »', 'image': 'https://img.lemde.fr/2023/11/14/0/0/5855/3903/110/73/60/0/59f5dd4_5871354-01-06.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Du cartel mexicain de Sinaloa aux rues de New York : au cœur du business du fentanyl', 'image': 'https://img.lemde.fr/2023/11/01/0/150/1620/1080/110/73/60/0/c5f2dd8_1698857249755-sei-quence-03-01-37-14-13-still136.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Pour lutter contre les rendez-vous médicaux non honorés, le Sénat vote le principe d’une taxe forfaitaire', 'image': 'https://img.lemde.fr/2023/07/10/0/0/5149/3433/110/73/60/0/69f166f_1688973943036-000-1r56f0.jpeg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Santé : « La prévention des cancers ORL doit être considérée comme un véritable enjeu de santé publique »', 'image': 'https://img.lemde.fr/2023/11/16/0/10/5595/3730/110/73/60/0/84f096b_1700141015525-pns-2090328.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Toques en stock aux fourneaux contre les inégalités nutritionnelles', 'image': 'https://img.lemde.fr/2023/11/13/0/0/1500/1000/110/73/60/0/7985a3c_310144-3347048.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'La puff va-t-elle faire pschitt ?', 'image': 'https://img.lemde.fr/2023/11/15/1248/0/2292/1528/110/73/60/0/31a7f25_1700047804299-635-sem-objet.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'La régulation de la charge de travail, grande oubliée du management', 'image': 'https://img.lemde.fr/2023/11/15/0/0/4612/3075/110/73/60/0/de36a0a_1700059785788-000-33w83kz.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Fin de vie : que dit la loi actuelle ? Comprendre en trois minutes', 'image': 'https://img.lemde.fr/2023/11/14/0/42/456/304/110/73/60/0/aa651f0_1699981768484-findevie.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Le « Lancet Countdown » mesure les effets alarmants du changement climatique sur la santé', 'image': 'https://img.lemde.fr/2023/11/14/0/0/3000/2000/110/73/60/0/4837187_1699971667412-903042.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Fin de vie : Emmanuel Macron tarde à trancher certains points du projet de loi', 'image': 'https://img.lemde.fr/2023/11/14/267/0/4000/2666/110/73/60/0/cd3a7b3_1699952000167-kzihnioglu-macron-armistice-11092023-07.JPG', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Des soignants racontent comment ils se sont forgé une conviction sur l’euthanasie : « C’est moi qui vais m’en rappeler tous les jours de ma vie »', 'image': 'https://img.lemde.fr/2023/11/10/390/0/4480/2986/110/73/60/0/f4d36a6_1699628779166-231030jbalague-monde-findevie-025.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Impact des écrans sur les enfants : une méta-analyse fait état d’effets d’intensité « faible à modérée »', 'image': 'https://img.lemde.fr/2023/11/13/0/4/4920/3280/110/73/60/0/78b05e9_1699869905398-000-par7656082.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Au Liberia, la jeunesse ravagée par la drogue', 'image': 'https://img.lemde.fr/2023/11/03/4/0/4464/2976/110/73/60/0/c17576b_1699020677961-fumei-e.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Fin de vie : « Mesure-t-on le risque d’ouvrir le chantier vertigineux de la légitimité de la demande d’accéder à la mort ? »', 'image': 'https://img.lemde.fr/2023/06/21/0/100/5041/3361/110/73/60/0/aa362f2_1687363479139-pns-4714163.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Un quatrième mort dans un Ehpad d’Ille-et-Vilaine, après une probable intoxication alimentaire', 'image': 'https://img.lemde.fr/2023/10/23/0/0/5860/3907/110/73/60/0/0ac1c14_1698072441024-hanslucas-hl-aboureau-2138702.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Si nous n’agissons pas, les changements climatiques conduiront bientôt à la submersion des systèmes de santé du monde entier »', 'image': 'https://img.lemde.fr/2022/03/30/216/0/5184/3456/110/73/60/0/f88a43e_1648623765275-pns-3924713.jpg', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Suppression de l’AME : 3 500 médecins menacent de désobéir si l’aide médicale d’Etat disparaît', 'image': 'https://img.lemde.fr/2020/10/16/0/0/3500/2333/110/73/60/0/386c1f3_gggpr05-health-coronavirus-france-hospital-1016-11.JPG', 'description': None}
# 2023-11-28 15:48:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Etre un père présent à l’accouchement, oui, mais comment ?', 'image': 'https://img.lemde.fr/2023/10/09/0/378/1961/1307/110/73/60/0/b235177_1696845556808-s3-eu-west-1-wellcomecollection-storage-digitised-b12025069-v1-data-objects-v0017247-ra-ra-jp2.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/campus/> (referer: https://www.lemonde.fr)
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Les difficultés des étudiants souffrant d’un trouble de l’attention : « Pourquoi j’ai cette impression de ne pas fonctionner comme les autres ? »', 'image': 'https://img.lemde.fr/2023/11/27/181/0/7543/5028/110/73/60/0/96a9a0e_1701081415992-tdah-clr.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Education : « Pourquoi n’envisageons-nous pas que les élèves les plus avancés puissent sauter la classe de CM2 ou la 6\u1d49 ? »', 'image': 'https://img.lemde.fr/2023/03/02/0/0/6000/4000/110/73/60/0/4656cf5_1677770202773-000-9m34fn.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Pourquoi les groupes de niveau au collège pourraient accroître les inégalités sans élever le niveau général', 'image': 'https://img.lemde.fr/2023/11/27/57/0/7268/4845/110/73/60/0/afda881_1701097189279-000-33rb7jh.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Finale des championnats d’Europe. Arrivée au milieu, je déchire mon dossard. Le début d’une descente aux enfers »', 'image': 'https://img.lemde.fr/2023/10/26/0/0/3543/2362/110/73/60/0/d12e60a_1698331746805-premiei-re-fois-lemonde-01.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Dominique Méda, sociologue : « Cessons de répéter que les jeunes ne veulent plus travailler »', 'image': 'https://img.lemde.fr/2023/11/23/1/0/6000/4000/110/73/60/0/b01418e_5945822-01-06.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Déçus par Parcoursup, comment avez-vous rebondi ?', 'image': 'https://img.lemde.fr/2023/05/22/0/0/2125/1417/110/73/60/0/c9aa0cb_1684760189910-parcoursup-choix2-exe.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'L’alcool sur les campus, une problématique épineuse pour les écoles et les universités', 'image': 'https://img.lemde.fr/2013/07/29/6/0/1024/683/110/73/60/0/ill_3454886_e0a6_binge.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Les « Rich Kids of Instagram », ces fils et filles à papa vantards et flambeurs', 'image': 'https://img.lemde.fr/2023/11/15/610/0/1890/1260/110/73/60/0/ce11491_1700044216768-115da50-1686048314389-v2.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Carole Grandjean, ministre déléguée chargée de l’enseignement professionnel : « En terminale, nous proposerons des parcours différenciés aux élèves selon leur projet »', 'image': 'https://img.lemde.fr/2023/11/21/0/0/5568/3712/110/73/60/0/2bdfb3e_1700577830198-000-32fa4fz.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'En école de commerce, l’endettement des étudiants s’aggrave : « Je n’ai pas le droit à l’erreur et plus vraiment de flexibilité dans le choix de mon orientation »', 'image': 'https://img.lemde.fr/2023/11/21/426/0/4423/2948/110/73/60/0/25b16da_1700559341065-2-3.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Ces vingtenaires qui se détournent de l’alcool : « Tu as l’impression que c’est un anxiolytique rapide, mais, le lendemain, tu doubles ton angoisse »', 'image': 'https://img.lemde.fr/2023/11/20/90/0/7543/5028/110/73/60/0/95c0deb_1700474360004-sobriei-tei-clr.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Pour les écoles de commerce, la voie royale de la prépa n’est devenue qu’une option parmi d’autres', 'image': 'https://img.lemde.fr/2023/11/17/15/0/1280/853/110/73/60/0/534f914_1700212209088-4-5-web.jpeg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Au lycée, tous les élèves qui ne sont pas originaires d’Europe occidentale sont qualifiés de “blédards”. A Sciences Po, je suis devenu “étudiant international” »', 'image': 'https://img.lemde.fr/2023/10/26/0/0/3543/2362/110/73/60/0/d12e60a_1698331746805-premiei-re-fois-lemonde-01.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'L’année de césure, une parenthèse pour bien choisir : « C’est tellement normal de ne pas bien savoir où l’on va quand on a 20 ans »', 'image': 'https://img.lemde.fr/2023/11/16/0/0/3000/2000/110/73/60/0/1dae624_1700127947834-le-temps-des-ei-tudiants.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Zerocalcare, bédéaste italien : « J’ai connu, d’un côté, la vie dans un quartier populaire. De l’autre, un univers exclusif, international et cultivé. Partout, j’étais en décalage »', 'image': 'https://img.lemde.fr/2023/11/08/64/0/2133/1422/110/73/60/0/f678bbf_1699438737671-zerocalcare-foto-di-rosdiana-ciaravolo.jpeg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Participez à la conférence « A 20 ans, faut-il perdre du temps pour en gagner ? », le 28 novembre au « Monde »', 'image': 'https://img.lemde.fr/2023/11/16/0/0/3000/2000/110/73/60/0/1dae624_1700127947834-le-temps-des-ei-tudiants.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Parcoursup : étudiants, parents d’élèves, vous avez fait le choix d’un établissement en dehors de la plate-forme, racontez-nous', 'image': 'https://img.lemde.fr/2023/07/06/0/0/1024/682/110/73/60/0/acf71cc_1688644928939-adobestock-203857417-1024x683.jpeg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'L’essor des stages ouvriers dans les écoles de commerce pour se frotter au réel : « J’apprends à travailler en équipe »', 'image': 'https://img.lemde.fr/2023/11/04/0/0/6000/4000/110/73/60/0/c5cdbbe_1699096714235-bod2023133n-9162.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Le Monde » organise le Salon des formations artistiques, les 9 et 10 décembre à Paris', 'image': 'https://img.lemde.fr/2023/11/13/0/0/2121/1414/110/73/60/0/00c9a72_1699874469436-istock-start-2023.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Gabriel Attal fait état de « résultats inquiétants » des élèves de 4e en français et en mathématiques', 'image': 'https://img.lemde.fr/2023/11/09/0/4/7032/4688/110/73/60/0/0740ce8_5828333-01-06.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Bac 2024 : la lourdeur des programmes inquiète les professeurs de terminale', 'image': 'https://img.lemde.fr/2023/10/13/0/0/6000/4000/110/73/60/0/d0c4e6f_1697197232571-000-33uc2g6.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Le destin bousculé des étudiants aidants : « J’étais épuisée physiquement et moralement, je me suis dit que je n’arriverais pas à tout concilier »', 'image': 'https://img.lemde.fr/2023/11/13/90/0/7543/5028/110/73/60/0/a705866_1699871012358-aidants-clr.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Jeune chercheuse ou chercheur, à quoi rêvez-vous ?', 'image': 'https://img.lemde.fr/2018/10/28/0/4/4920/3280/110/73/60/0/f876b36_9eDI6Qg600ZGSRyinoVU2prg.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Mon master : premier bilan mitigé pour la nouvelle plate-forme', 'image': 'https://img.lemde.fr/2023/11/12/0/0/6000/4000/110/73/60/0/7fc12a5_1699827130150-080-hl-jmbarrere-2116205.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Mes parents ont tout fait pour qu’on soit catholiques, vieille France, et ça n’a pas vraiment pris »', 'image': 'https://img.lemde.fr/2023/11/07/0/0/3543/2362/110/73/60/0/f45fb73_1699383816451-premiei-re-fois-lemonde-02.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Face aux désordres sociaux ou environnementaux, les petits gestes suffiront-ils à faire advenir les grands changements ?', 'image': 'https://img.lemde.fr/2023/11/07/398/0/5272/3514/110/73/60/0/9920c4f_1699367165336-lon57116.jpeg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Aux arts et métiers, les traditions de l’école perpétuent l’esprit de corps', 'image': 'https://img.lemde.fr/2023/11/09/0/0/2125/1417/110/73/60/0/73a393d_1699559763279-hd-copie.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'La « situationship », un flou relationnel qui se répand chez les jeunes : « C’est horrible, comme mot, l’engagement ! On dirait la fin de quelque chose »', 'image': 'https://img.lemde.fr/2023/11/08/27/0/2220/1480/110/73/60/0/67e221c_1699457290791-situationship-chiaradattola.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'En Californie, vingt ans après la fin de la discrimination positive, les résultats à l’université déçoivent', 'image': 'https://img.lemde.fr/2021/03/04/0/0/4368/2912/110/73/60/0/e82c29f_5573836-pns-796543.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Aux Etats-Unis, la rentrée signe la fin de la discrimination positive à l’université : « Beaucoup de jeunes Noirs et Latinos se demandent s’ils ont leur place »', 'image': 'https://img.lemde.fr/2023/11/06/90/0/7543/5028/110/73/60/0/d61a170_1699267236473-affirmativeaction-clr.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« L’université sera l’un des piliers autour duquel nous pourrons remodeler notre cohésion sociale »', 'image': 'https://img.lemde.fr/2023/11/06/0/0/6192/4128/110/73/60/0/57671b8_1699258204165-000-336j8hq.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Il naît chez moi une passion pour les fleurs que je n’avais jamais ressentie dans l’ingénierie »', 'image': 'https://img.lemde.fr/2023/10/26/0/0/3543/2362/110/73/60/0/d12e60a_1698331746805-premiei-re-fois-lemonde-01.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Achraf Manar, « jour et nuit » contre l’injustice sociale', 'image': 'https://img.lemde.fr/2023/10/26/735/0/2362/1574/110/73/60/0/f2953a4_1698309229071-37a3609.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Le Monde » organise les Journées de l’orientation pour aider lycéens, étudiants et parents dans leurs choix d’études supérieures', 'image': 'https://img.lemde.fr/2023/11/02/350/0/8400/5600/110/73/60/0/7d80235_1698942797107-copie-de-2014165-os-n338.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Du bac pro aux écoles d’ingénieurs, un parcours rigoureux pour « fuir l’atelier et faire des études longues »', 'image': 'https://img.lemde.fr/2017/06/07/0/0/5760/3840/110/73/60/0/346bbf3_7493-7x0n1z.4dx98p8pvi.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Après les JO de Paris, plus de 1 600 logements pour athlètes et journalistes seront proposés à des étudiants', 'image': 'https://img.lemde.fr/2023/11/01/0/0/6000/4000/110/73/60/0/25aadba_1698851919431-000-339849f.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Logement étudiant : la longue quête des Crous pour bénéficier du foncier de l’Etat', 'image': 'https://img.lemde.fr/2023/11/01/0/0/4200/2800/110/73/60/0/2604d2a_1698850416912-hl-nliponne-1824099.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Ecoles de commerce : « Les associations étudiantes apprennent aux jeunes élites à se sentir comme telles »', 'image': 'https://img.lemde.fr/2023/10/30/0/0/4999/3333/110/73/60/0/79f0743_1698687050944-maxnewsworldfour969383.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Les associations étudiantes en école de commerce peinent à rompre avec les violences sexistes et le harcèlement', 'image': 'https://img.lemde.fr/2023/10/30/181/0/7543/5028/110/73/60/0/c24b2e3_1698654944694-sexismeecolecommerce-clr.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Face à l’intensification du travail, les jeunes plongent dans un malaise profond : « Je m’enfonçais dans le travail, je n’avais plus de distance »', 'image': 'https://img.lemde.fr/2023/10/26/0/130/2869/1913/110/73/60/0/0d71c21_1698313876721-le-monde-absenta-isme-def-v1.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Face à mon échec en médecine, ma mère s’effondre en sanglots. Et c’est là que je comprends : tous mes échecs seront les siens »', 'image': 'https://img.lemde.fr/2023/10/26/0/0/3543/2362/110/73/60/0/d12e60a_1698331746805-premiei-re-fois-lemonde-01.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'L’exode des Parisiens à fort pouvoir d’achat vers la côte basque déstabilise et irrite parfois les locaux : « Ils ne reconnaissent pas l’endroit où ils ont grandi »', 'image': 'https://img.lemde.fr/2023/10/10/0/25/5340/3560/110/73/60/0/60fc6ff_1696948911871-000-33wz7qy.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Après un MBA financé par leur entreprise, les cadres parfois tentés « d’aller voir ailleurs »', 'image': 'https://img.lemde.fr/2023/10/23/0/0/600/400/110/73/60/0/c4ccd8b_1698069654953-divergence-cf0839003.JPG', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Quand les métiers d’art se pratiquent en famille', 'image': 'https://img.lemde.fr/2023/10/24/0/0/6240/4160/110/73/60/0/3771e6d_1698139318704-le-monde-artisanat-art-10-1.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Ces jeunes cadres atteints du syndrome de l’imposteur', 'image': 'https://img.lemde.fr/2023/10/23/0/59/2125/1417/110/73/60/0/c683a13_1698054182669-le-monde-imposteur-def.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Les écoles d’art et de design bousculées par les intelligences artificielles génératives : « Ça m’intéresse de savoir les dompter pour ne pas me faire remplacer »', 'image': 'https://img.lemde.fr/2023/10/20/90/0/7543/5028/110/73/60/0/29e192d_1697793001268-intelligenceartificielle-clr.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Au travail, j’entends parfois : “Tu n’es pas comme eux”, sous-entendu comme les jeunes de banlieue qui font des conneries »', 'image': 'https://img.lemde.fr/2022/09/22/0/0/3543/2362/110/73/60/0/8bf0863_1663835540624-le-monde-campus-colo-v02.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'De retour à Sciences Po, Fariba Adelkhah appelle à la défense de la liberté académique', 'image': 'https://img.lemde.fr/2023/10/20/0/0/5092/3395/110/73/60/0/f5a08eb_5634848-01-06.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Plongée dans les « prisons dorées » des multinationales : « C’était irrésistible. A 30 ans, je triplais, voire quadruplais mon salaire »', 'image': 'https://img.lemde.fr/2023/10/19/748/0/2244/1496/110/73/60/0/6a82b00_1697699732329-le-monde-prison-dorei-e-def-v2.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Agnès van Zanten, sociologue : « L’orientation subie est un échec vécu de façon très violente »', 'image': 'https://img.lemde.fr/2023/10/16/0/0/2362/1574/110/73/60/0/40aadfc_1697458765941-000-33jk2dw.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Participez à « Place de la République », un événement du « Monde », à Lyon, le 18 novembre', 'image': 'https://img.lemde.fr/2019/03/16/0/6/5488/3659/110/73/60/0/1570572_5449820-01-06.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Préparer les étudiants aux difficultés des métiers « responsables », un enjeu pour les formations', 'image': 'https://img.lemde.fr/2023/10/09/213/0/3386/2257/110/73/60/0/06fae82_1696867168246-v1-illu3-campus.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Tout professeur qui déclare “ne pas être raciste” est “dans le déni”, selon le nouveau règlement en vigueur dans des universités de Californie »', 'image': 'https://img.lemde.fr/2021/04/22/0/36/2928/1952/110/73/60/0/f88405e_c21e26aa2fde44109cd9635678381691-c21e26aa2fde44109cd9635678381691-0.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« J’ai pas le niveau ! » : à Nanterre, les jeunes pris dans la mécanique de l’échec scolaire', 'image': 'https://img.lemde.fr/2023/10/16/181/0/7543/5028/110/73/60/0/447160f_1697445501428-nanterre-clr-01.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Le mythe de la déconnexion entre les universités et le monde du travail', 'image': 'https://img.lemde.fr/2023/07/12/0/17/4516/3011/110/73/60/0/d7f35c4_1689171508719-000-ta8po.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Le Collège de Monsieur Paty », sur France 2 : deuil à huis clos', 'image': 'https://img.lemde.fr/2023/10/13/0/150/1620/1080/110/73/60/0/6810380_1697203590551-lecollegedemonsieurpaty.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Le Monde » organise le MBA Fair, le Salon des MBA et Executive Masters, le 7 novembre 2023 à Paris', 'image': 'https://img.lemde.fr/2023/10/16/0/0/2400/1600/110/73/60/0/a86d067_1697445255246-siege-groupe-le-monde-credit-jared-chulksi-2x.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Les MBA se féminisent, non sans difficultés : « Le plus gros problème des femmes, c’est qu’elles doutent d’elles-mêmes »', 'image': 'https://img.lemde.fr/2023/10/15/0/59/2125/1417/110/73/60/0/2a846b3_1697375251984-le-monde-mba-def-v2.jpg', 'description': None}
# 2023-11-28 15:48:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# ...
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : à Jérusalem-Est, la libération sous tension des prisonniers palestiniens', 'image': 'https://img.lemde.fr/2023/11/25/0/0/6000/4000/110/73/60/0/88b5c60_1700896165075-asurp-israel-100291.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : l’effarement à Gaza, où règne « un niveau de destruction absolue »', 'image': 'https://img.lemde.fr/2023/11/25/0/0/6253/4168/110/73/60/0/7e56d55_1700895143868-927807.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : « Il convient de tout faire pour prolonger la trêve, de façon qu’elle se transforme en un véritable cessez-le-feu »', 'image': 'https://img.lemde.fr/2023/11/24/0/0/3696/2464/110/73/60/0/8517c5c_5956293-01-06.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : vingt-quatre otages ont été libérés par le Hamas au premier jour de la trêve', 'image': 'https://img.lemde.fr/2023/11/24/0/0/5616/3744/110/73/60/0/f08ca84_c3f3fd5ab7f34e98ac7c18bdf6eb6e89-1-da43f159e47c47a7a3e0f0529ba4777d.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : la Cisjordanie peut-elle devenir un nouveau front ? Comprendre en trois minutes', 'image': 'https://img.lemde.fr/2023/11/24/0/150/1620/1080/110/73/60/0/f04c84b_1700823560945-tilehori-00233.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Selon Israël, 200 camions d’aide humanitaire sont entrés dans la bande de Gaza ainsi que 4 camions d’essence et 4 citernes de gaz', 'image': 'https://img.lemde.fr/2023/11/24/0/0/3696/2464/110/73/60/0/7f7020e_5955682-01-06.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Les images de la libération des premiers otages détenus par le Hamas', 'image': 'https://img.lemde.fr/2023/11/24/22/0/1821/1214/110/73/60/0/eaa085e_2023-11-24t163416z-1066879186-rc2mj4arr4wl-rtrmadp-3-israel-palestinians-hostages-egypt.JPG', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Au Maroc, l’ancien premier ministre islamiste Abdelilah Benkirane dérape dans l’antisémitisme', 'image': 'https://img.lemde.fr/2023/11/24/0/8/4233/2822/110/73/60/0/d098b78_1700830945262-000-mq0m2.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : pourquoi les négociations lors des prises d’otages sont si compliquées ?', 'image': 'https://img.lemde.fr/2023/11/24/0/0/5502/3668/110/73/60/0/e8350d1_5953806-01-06.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Les premiers otages israéliens libérés devraient être répartis dans six hôpitaux', 'image': 'https://img.lemde.fr/2023/11/23/0/0/8640/5760/110/73/60/0/aaded35_a0c0c95235144ae0a18ad5990378b77f-0-b7d0825a1aa4450eb1c7ed1f3c103354.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'En Israël, l’accord avec le Hamas ne fait pas l’unanimité', 'image': 'https://img.lemde.fr/2023/11/24/0/0/6000/4000/110/73/60/0/d5dbcaf_1700813718986-asurp-israel-108162.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Yagil Levy, sociologue : « Le système politique d’Israël est complètement paralysé »', 'image': 'https://img.lemde.fr/2023/11/23/357/0/4000/2666/110/73/60/0/714921c_1700758764900-asurp-israel-108302.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Libération des otages du Hamas : « Une situation aussi déchirante sur le plan éthique n’a pas vraiment de précédent »', 'image': 'https://img.lemde.fr/2023/11/22/0/0/5395/3596/110/73/60/0/6ae8856_5942680-01-06.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'TV5Monde désavoue l’interview d’un militaire israélien par l’un de ses journalistes et provoque des remous dans la rédaction', 'image': 'https://img.lemde.fr/2015/04/09/0/0/3000/2000/110/73/60/0/ill_4613309_d383_000_par519405.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'La trajectoire de Yahya Sinouar, du camp de réfugiés de Khan Younès aux commandes de l’attaque du 7 octobre', 'image': 'https://img.lemde.fr/2023/11/21/0/139/832/555/110/73/60/0/7a47773_1700580026027-mei-dia-d-appel-web-hamas-petit.png', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Après le sketch polémique de Guillaume Meurice, l’Arcom adresse une mise en garde à Radio France', 'image': 'https://img.lemde.fr/2023/11/23/0/1/4354/2903/110/73/60/0/c202937_1700766362724-000-33al7t6.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Israël-Palestine, deux familles dans le fracas de l’histoire', 'image': 'https://img.lemde.fr/2023/11/23/0/0/1920/1280/110/73/60/0/a6696dd_1700746621857-media-appel.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'En Israël, le rêve de pionniers des Weissmann', 'image': 'https://img.lemde.fr/2023/11/21/276/0/2598/1732/110/73/60/0/411175d_313817-3347580.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'La Palestine, patrie introuvable de la famille Redwan', 'image': 'https://img.lemde.fr/2023/11/21/79/0/1500/1000/110/73/60/0/e2eec39_313825-3348010.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'L’espoir retrouvé de la famille de Marah Bakir, sur la liste des prisonniers palestiniens devant être libérés', 'image': 'https://img.lemde.fr/2023/11/23/0/0/6000/4000/110/73/60/0/eea30be_1700701445008-asurp-israel-108330.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Le Qatar, acteur-clé dans les discussions entre Israël et le Hamas', 'image': 'https://img.lemde.fr/2023/11/22/0/0/3193/2129/110/73/60/0/e607779_1700671913337-000-33zu7qj.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : ce que l’on sait de l’accord conclu pour la libération d’otages', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/5e763a2_1700618223301-asurp-israel-107136.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : à Rafah, des rescapés de Gaza sous le choc et des tonnes d’aide humanitaire en attente', 'image': 'https://img.lemde.fr/2023/11/22/0/0/5961/3974/110/73/60/0/cb25a43_5942271-01-06.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A São Paulo, la concorde entre juifs et musulmans ébranlée', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1500/1000/110/73/60/0/830b0a0_313932-3348232.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : tout comprendre à l’accord sur les otages', 'image': 'https://img.lemde.fr/2023/11/22/0/0/1800/1200/110/73/60/0/9653e6f_1700646514333-photo-accord-otage3.png', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Tel-Aviv, les espoirs et les craintes des familles d’otages du Hamas dans l’attente des premières libérations', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/02cc707_1700666626393-asurp-israel-108198.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Les Etats-Unis ont intercepté des drones d’attaque lancés depuis le Yémen', 'image': 'https://img.lemde.fr/2021/04/03/0/3/3493/2329/110/73/60/0/fbe6a46_navy-ho-001-egypt-suezcanal-ship-us-navy-0403-11.JPG', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Paris, une instagrameuse jugée pour apologie du terrorisme', 'image': 'https://img.lemde.fr/2023/11/22/0/0/5229/3486/110/73/60/0/360464d_1700667986630-000-33yl7gq.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : quatre Libanais, dont deux journalistes, tués dans des frappes israéliennes', 'image': 'https://img.lemde.fr/2023/11/22/0/85/5638/3759/110/73/60/0/bc0d068_1700641183480-220460.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : récit des cinq semaines de discussions qui ont abouti à un accord pour des premières libérations d’otages', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/5e763a2_1700618223301-asurp-israel-107136.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Les BRICS+ ne parviennent pas à s’accorder sur la guerre à Gaza face à l’Occident', 'image': 'https://img.lemde.fr/2023/11/22/0/46/3039/2026/110/73/60/0/4082b6e_1700640604803-921861.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Tel-Aviv, l’insupportable attente des familles d’otages', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/dff4a1e_1700618171413-asurp-israel-107086.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Joe Biden et Israël : une amitié à l’épreuve du feu', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1800/1200/110/73/60/0/f8a1c2d_1700564532431-biden-et-israel.png', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : la question des prisonniers palestiniens au cœur du conflit', 'image': 'https://img.lemde.fr/2023/11/19/387/0/4628/3085/110/73/60/0/fb3dea9_1700389582890-13112023-l3140238.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'L’Union européenne poursuit son aide au développement en faveur de la Palestine', 'image': 'https://img.lemde.fr/2023/11/21/0/0/5472/3648/110/73/60/0/91576ca_1700590530398-000-344a3em.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Au Maroc, les groupes Carrefour et McDonald’s ciblés par un boycott sur fond de guerre à Gaza', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1024/682/110/73/60/0/b355ed2_1700575647391-000-app2003052684484.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : suspendues aux négociations, les familles d’otages entre angoisse et colère', 'image': 'https://img.lemde.fr/2023/11/21/0/126/5874/3916/110/73/60/0/429c885_1700555544965-asurp-israel-105335.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : « Il nous faut désormais résister au vertige et à l’ivresse de la vengeance »', 'image': 'https://img.lemde.fr/2023/11/20/0/190/3189/2126/110/73/60/0/38bae52_5926154-01-06.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Sommet des BRICS : l’Afrique du Sud accuse Israël de « crimes de guerre » et « génocide » à Gaza', 'image': 'https://img.lemde.fr/2023/11/21/0/0/3868/2578/110/73/60/0/c2d0783_1700577056273-000-344839t.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : à Paris, le drame personnel de l’ambassadrice palestinienne, Hala Abou Hassira', 'image': 'https://img.lemde.fr/2023/11/21/507/0/7613/5075/110/73/60/0/df45b2e_1700555810159-ll-hala-abou-hassira-02.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Vidéo : les rebelles houthistes du Yémen se sont emparés d’un navire en mer Rouge', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1620/1080/110/73/60/0/daa324e_ae4d7f9f6cad407da609d926fe2c14cc-0-160067ee41d849bbad582ec10ba3da44.jpg', 'description': None}
# 2023-11-28 15:48:10 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-28 15:48:10 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 12252,
#  'downloader/request_count': 31,
#  'downloader/request_method_count/GET': 31,
#  'downloader/response_bytes': 2542220,
#  'downloader/response_count': 31,
#  'downloader/response_status_count/200': 31,
#  'elapsed_time_seconds': 6.212947,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 28, 14, 48, 10, 84119, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 10111110,
#  'httpcompression/response_count': 31,
#  'item_scraped_count': 1522,
#  'log_count/DEBUG': 1556,
#  'log_count/ERROR': 3,
#  'log_count/INFO': 10,
#  'request_depth_max': 1,
#  'response_received_count': 31,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 30,
#  'scheduler/dequeued/memory': 30,
#  'scheduler/enqueued': 30,
#  'scheduler/enqueued/memory': 30,
#  'spider_exceptions/IndexError': 3,
#  'start_time': datetime.datetime(2023, 11, 28, 14, 48, 3, 871172, tzinfo=datetime.timezone.utc)}
# 2023-11-28 15:48:10 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On peut exporter les résultats de ces retours dans différents formats de
# fichiers.
#
# -   CSV : `scrapy crawl lemonde -o lbc.csv`
# -   JSON : `scrapy crawl lemonde -o lbc.json`
# -   JSONLINE : `scrapy crawl lemonde -o lbc.jl`
# -   XML : `scrapy crawl lemonde -o lbc.xml`
#
# ### Exercice :
#
# Exécuter la spider avec les différents formats de stockage.
# Explorer ensuite le contenu des fichiers ainsi créés.

# %%
# !scrapy
# Out:
# Scrapy 2.11.0 - no active project
#
# Usage:
#   scrapy <command> [options] [args]
#
# Available commands:
#   bench         Run quick benchmark test
#   fetch         Fetch a URL using the Scrapy downloader
#   genspider     Generate new spider using pre-defined templates
#   runspider     Run a self-contained spider (without creating a project)
#   settings      Get settings values
#   shell         Interactive scraping console
#   startproject  Create new project
#   version       Print Scrapy version
#   view          Open URL in browser, as seen by Scrapy
#
#   [ more ]      More commands available when run from project directory
#
# Use "scrapy <command> -h" to see more info about a command

# %% [markdown]
# ## Votre premier Item
#
# La classe `Item` permet de structurer les données que l'on souhaite
# récupérer sous la forme d'un modèle. Les items doivent être définis dans
# le fichier `items.py` créé par la commande `scrapy startproject`. Les
# `Item` héritent de la class `scrapy.Item`.
#
# On veut structurer les données avec deux champs : le titre et le prix de
# l'annonce. Scrapy utilise une classe `scrapy.Field` permettant de
# 'déclarer' ces champs. Dans notre cas :

# %%
# %load newscrawler/newscrawler/items.py

# Define here the models for your scraped items
#
# See documentation in:
# https://docs.scrapy.org/en/latest/topics/items.html

import scrapy

class ArticleItem(scrapy.Item):
    title = scrapy.Field()
    image = scrapy.Field()
    description = scrapy.Field()

# %% [markdown]
# Utiliser la classe `scrapy.Item` plutôt qu'un simple dictionnaire permet
# plus de contrôle sur la structure des données. En effet, on ne peut
# insérer dans les items que des données avec des clés 'déclarées'. Ce qui
# assure une plus grande cohérence au sein d'un projet.
#
# On peut instancier un item de plusieurs façons :

# %%
article_item = ArticleItem(title="Gilets Jaunes", image=None, description="Un samedi de manifestations")

# %%
print(article_item)
# Out:
# {'description': 'Un samedi de manifestations',
#  'image': None,
#  'title': 'Gilets Jaunes'}

# %%
article_item = ArticleItem()
article_item["title"] = 'Gilets Jaunes'
article_item["description"] = 'Un samedi de manifestations'

# %%
print(article_item)
# Out:
# {'description': 'Un samedi de manifestations', 'title': 'Gilets Jaunes'}

# %% [markdown]
# La définition d'un item permet de palier toutes les erreurs de typo dans
# les champs.

# %%
article_item = ArticleItem()
article_item["titelkjwnxvmnscbvmknxc"] = 'Gilets Jaunes'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-f12882ec7441> in <module>
#       1 article_item = ArticleItem()
# ----> 2 article_item["titelkjwnxvmnscbvmknxc"] = 'Gilets Jaunes'
#
# //anaconda3/lib/python3.7/site-packages/scrapy/item.py in __setitem__(self, key, value)
#      96         else:
#      97             raise KeyError("%s does not support field: %s" %
# ---> 98                 (self.__class__.__name__, key))
#      99
#     100     def __delitem__(self, key):
#
# KeyError: 'ArticleItem does not support field: titelkjwnxvmnscbvmknxc'

# %% [markdown]
# Les items héritent des dictionnaires Python, et possèdent donc toutes
# les méthodes de ceux-ci:

# %%
article_item = ArticleItem(title="Gilets Jaunes")
print(article_item["title"]) # Méthode __getitem__()
print(article_item.get("description", "no description provided")) # Méthode get()
# Out:
# Gilets Jaunes
# no description provided

# %% [markdown]
# On peut transformer un `Item` en dictionnaire très facilement, en le
# passant au constructeur:

# %%
article_item = ArticleItem(title="Drone DJI")
print(type(article_item))
dict_item = dict(article_item)
print(type(dict_item))
print(dict_item)
# Out:
# <class '__main__.ArticleItem'>
# <class 'dict'>
# {'title': 'Drone DJI'}

# %% [markdown]
# On intègre maintenant cet item dans notre spider.

# %%
# -*- coding: utf-8 -*-
import scrapy
from scrapy import Request
from ..items import ArticleItem
class LemondeSpider(scrapy.Spider):
    name = "lemonde"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name:response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        for link in all_links.values():
            yield Request(link, callback=self.parse_category)

    def parse_category(self, response):
        for article in response.css(".fleuve")[0].css("article"):
            title = self.clean_spaces(article.css("h3 a::text").extract_first())
            image = article.css("img::attr(data-src)").extract_first()
            description = article.css(".txt3::text").extract_first()

            yield ArticleItem(
                title=title,
                image=image,
                description=description
            )

    def clean_spaces(self, string):
        if string:
            return " ".join(string.split())

# %% [markdown]
# On voit bien que le générateur retourne maintenant un `Item`.

# %% [markdown]
# ### Exercice :
#
# Relancer la spider pour vérifier le bon déroulement de l'extraction.

# %%
# !cd newscrawler/ && scrapy crawl lemondev4
# Out:
# 2023-11-28 16:00:55 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-11-28 16:00:55 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22631-SP0
# 2023-11-28 16:00:55 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-28 16:00:55 [asyncio] DEBUG: Using selector: SelectSelector
# 2023-11-28 16:00:55 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-11-28 16:00:55 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2023-11-28 16:00:55 [scrapy.extensions.telnet] INFO: Telnet Password: ec5a4faa6e5dd1c6
# 2023-11-28 16:00:55 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-28 16:00:55 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-11-28 16:00:55 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-28 16:00:55 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-28 16:00:55 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-28 16:00:55 [scrapy.core.engine] INFO: Spider opened
# 2023-11-28 16:00:55 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-28 16:00:55 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-11-28 16:00:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-11-28 16:00:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2023-11-28 16:00:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/pixels/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:00:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:00:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/podcasts/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:00:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/intimites/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:00:59 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/pixels/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:00:59 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:00:59 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/podcasts/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:00:59 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/intimites/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:00:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-fil-good/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:00:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sciences/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:00:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/disparitions/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:00:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/education/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:00:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sport/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:00:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# 2023-11-28 16:00:59 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/le-fil-good/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:00:59 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/sciences/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:00:59 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/disparitions/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:00:59 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/education/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:00:59 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/sport/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:00:59 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:00:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/campus/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:00:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sante/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:01:00 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/campus/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:01:00 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/sante/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:01:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/societe/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:01:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/afrique/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:01:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/les-decodeurs/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:01:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/actualite-en-continu/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:01:00 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/societe/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:01:01 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/les-decodeurs/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
# ...
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:01:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/crise-ukrainienne/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:01:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/antisemitisme/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:01:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/immigration-et-diversite/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:01:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/attaque-du-hamas-contre-israel/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:01:02 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/crise-ukrainienne/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:01:02 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/antisemitisme/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:01:02 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/immigration-et-diversite/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:01:02 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/attaque-du-hamas-contre-israel/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\antoi\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde.py", line 23, in parse_category
#     for article in response.css(".fleuve")[0].css("article"):
#                    ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\antoi\AppData\Local\Programs\Python\Python311\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:01:02 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-28 16:01:02 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 12252,
#  'downloader/request_count': 31,
#  'downloader/request_method_count/GET': 31,
#  'downloader/response_bytes': 2542538,
#  'downloader/response_count': 31,
#  'downloader/response_status_count/200': 31,
#  'elapsed_time_seconds': 6.292599,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 28, 15, 1, 2, 133411, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 10103525,
#  'httpcompression/response_count': 31,
#  'log_count/DEBUG': 34,
#  'log_count/ERROR': 29,
#  'log_count/INFO': 10,
#  'request_depth_max': 1,
#  'response_received_count': 31,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 30,
#  'scheduler/dequeued/memory': 30,
#  'scheduler/enqueued': 30,
#  'scheduler/enqueued/memory': 30,
#  'spider_exceptions/IndexError': 29,
#  'start_time': datetime.datetime(2023, 11, 28, 15, 0, 55, 840812, tzinfo=datetime.timezone.utc)}
# 2023-11-28 16:01:02 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Postprocessing
#
# Si l'on se réfère au diagramme d'architecture de Scrapy, on voit qu'il
# est possible d'insérer des composants supplémentaires dans le flux de
# traitement. Ces composants s'appellent `Pipelines`.
#
# Par défaut, tous les `Item` générés au sein d'un projet Scrapy passent
# par les `Pipelines`. Les pipelines sont utilisés la plupart du temps
# pour :
#
# -   Nettoyer du contenu HTML ;
# -   Valider les données scrapées ;
# -   Supprimer les items qu'on ne souhaite pas stocker ;
# -   Stocker ces objets dans des bases de données.
#
# Les pipelines doivent être définis dans le fichier `pipelines.py`.
#
# Dans notre cas on peut vouloir nettoyer le champ `title` pour enlever
# les caractères superflus.
#
# Nous allons alors transferer la fonction de nettoyage du code html dans
# une Pipeline.

# %%
# %load newscrawler/newscrawler/pipelines.py

# Define your item pipelines here
#
# Don't forget to add your pipeline to the ITEM_PIPELINES setting
# See: https://docs.scrapy.org/en/latest/topics/item-pipeline.html

from scrapy.exceptions import DropItem

class TextPipeline(object):

    def process_item(self, item, spider):
        if item['title']:
            item["title"] = clean_spaces(item["title"])
            return item
        else:
            raise DropItem("Missing title in %s" % item)


def clean_spaces(string):
    if string:
        return " ".join(string.split())

# %% [markdown]
# Pour dire au process Scrapy de faire transiter les items par ces
# pipelines. Il faut le spécifier dans le fichier de paramétrage
# `settings.py`.

# %%
ITEM_PIPELINES = {
     'newscrawler.pipelines.TextPipeline': 300,
 }

# %% [markdown]
# On peut maintenant supprimer la fonction `clean_spaces()` de
# l'extraction des données et laisser le Pipeline faire son travail. La
# valeur entière définie permet de déterminer l'ordre dans lequel les
# pipelines vont être appelés. Ces entiers peuvent être compris entre 0 et
# 1000.
#
# On relance notre spider :

# %%
scrapy crawl lemonde -o ../data/articles.json

# %% [markdown]
# On peut aussi utiliser les Pipelines pour stocker les données récupérées
# dans une base de données. Pour stocker les items dans des documents
# mongo :

# %%
import pymongo

class MongoPipeline(object):

    collection_name = 'scrapy_items'

    def open_spider(self, spider):
        self.client = pymongo.MongoClient()
        self.db = self.client["lemonde"]

    def close_spider(self, spider):
        self.client.close()

    def process_item(self, item, spider):
        self.db[self.collection_name].insert_one(dict(item))
        return item

# %% [markdown]
# Ici on redéfinit deux autres méthodes: `open_spider()`et
# `close_spider()`, ces méthodes sont appelées comme leur nom l'indique,
# lorsque la Spider est instanciée et fermée.
#
# Ces méthodes nous permettent d'ouvrir la connexion Mongo et de la fermer
# lorsque le scraping se termine. La méthode `process_item()` est appelé à
# chaque fois qu'un item passe dans le mécanisme interne de scrapy. Ici,
# la méthode permet d'insérer l'item en tant que document mongo.
#
# Pour que ce pipeline soit appelé il faut l'ajouter dans les settings du
# projet.

# %%
ITEM_PIPELINES = {
    'newscrawler.pipelines.TextPipeline': 100,
    'newscrawler.pipelines.MongoPipeline': 300
}

# %% [markdown]
# Le pipeline est ajoutée à la fin du process pour profiter des deux
# précédents.
#
# ## Settings
#
# Scrapy permet de gérer le comportement des spiders avec certains
# paramètres. Comme expliqué dans le premier cours, il est important de
# suivre des règles en respectant la structure des différents sites. Il
# existe énormément de paramètres mais nous allons (dans le cadre de ce
# cours) aborder les plus utilisés :
#
# -   DOWNLOAD\_DELAY : Le temps de téléchargement entre chaque requête
#     sur le même domaine ;
# -   CONCURRENT\_REQUESTS\_PER\_DOMAIN : Nombre de requêtes simultanées
#     par domaine ;
# -   CONCURRENT\_REQUESTS\_PER\_IP : Nombre de requêtes simultanées par
#     IP ;
# -   DEFAULT\_REQUEST\_HEADERS : Headers HTTP utilisés pour les requêtes
#     ;
# -   ROBOTSTXT\_OBEY : Scrapy récupère le robots.txt et adapte le
#     scraping en fonction des règles trouvées ;
# -   USER\_AGENT : UserAgent utilisé pour faire les requêtes ;
# -   BOT\_NAME : Nom du bot annoncé lors des requêtes
# -   HTTPCACHE\_ENABLED : Utilisation du cache HTTP, utile lors du
#     parcours multiple de la même page.
#
# Le fichiers `settings.py` permet de définir les paramètres globaux d'un
# projet. Si votre projet contient un grand nombre de spiders, il peut
# être intéressant d'avoir des paramètres distincts pour chaque spider. Un
# moyen simple est d'ajouter un attribut `custom_settings` à votre spider
# :

# %%
class LeMondeSpider(scrapy.Spider):
        name = "lemonde"
        allowed_domains = ["lemonde.fr"]
        start_urls = ['http://lemonde.fr/']
        custom_settings = {
            "HTTPCACHE_ENABLED":True, 
            "CONCURRENT_REQUESTS_PER_DOMAIN":100
        }
